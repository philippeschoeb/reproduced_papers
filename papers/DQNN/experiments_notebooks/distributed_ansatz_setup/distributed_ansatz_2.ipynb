# %%
import torch
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import pandas as pd
from datetime import datetime
import time

# # Assuming evaluate is defined elsewhere
# # from your_module import evaluate
import torch.optim as optim

from tqdm.auto import tqdm
from collections.abc import Iterable
import perceval as pcvl
from boson_sampler import BosonSampler
import numpy as np
from scipy.optimize import minimize
import random
import matplotlib.pyplot as plt
from utils import MNIST_partial, accuracy, plot_training_metrics

# from model import MnistModel, evaluate
import torch.nn as nn
import torch.nn.functional as F

# simulator = pcvl.Simulator(pcvl.NaiveBackend())
from scipy.optimize import minimize

import warnings

warnings.filterwarnings("ignore")

# %%
# device = torch.device("cpu")
device = torch.device("cuda:0")

# %%
#### START SCALEWAY SESSION ####
session = None
# to run a remote session on Scaleway, uncomment the following and fill project_id and token
# session = scw.Session(
#                    platform="sim:sampling:p100",  # or sim:sampling:h100
#                    project_id=""  # Your project id,
#                    token=""  # Your personal API key
#                    )

# start session
if session is not None:
    session.start()

#### BOSON SAMPLER DEFINITION ####

bs_1 = BosonSampler(m=7, n=4, session=session)
print(
    f"Boson sampler defined with number of parameters = {bs_1.nb_parameters}, and embedding size = {bs_1.embedding_size}"
)
# to display it
pcvl.pdisplay(bs_1.create_circuit())
# Out:
# Boson sampler defined with number of parameters = 63, and embedding size = 35

# %%
bs_2 = BosonSampler(m=7, n=4, session=session)
print(
    f"Boson sampler defined with number of parameters = {bs_2.nb_parameters}, and embedding size = {bs_2.embedding_size}"
)
# to display it
pcvl.pdisplay(bs_2.create_circuit())
# Out:
# Boson sampler defined with number of parameters = 63, and embedding size = 35

# %%
35 * 35
# Out:
# 1225

# %%
# random_para_tensor = torch.randn(165)
# res = bs.run(
#     parameters=random_para_tensor,
#     samples=100000
# )

# trans_res = bs.translate_results(res = res)
# print(trans_res)

# %%
# print(torch.mean(trans_res))

# trans_res = trans_res/torch.mean(trans_res)

# print(torch.mean(trans_res))

# %%
# count = 0
# for i in trans_res:
#     if i != 0:
#         count += 1
#     # print(i)
# print("non zero counts:", count)

# %%
# print(len(trans_res))

# %%
# Define the CNN model
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 4, kernel_size=4)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(4, 4, kernel_size=4)
        self.fc1 = nn.Linear(4 * 4 * 4, 10)
        # self.fc2 = nn.Linear(20, 10)

    def forward(self, x):
        x = self.pool(self.conv1(x))
        x = self.pool(self.conv2(x))
        x = x.view(x.size(0), -1)  # [N, 32 * 8 * 8]
        x = self.fc1(x)
        # x = self.fc2(x)
        #     super(CNNModel, self).__init__()
        #     self.conv1 = nn.Conv2d(1, 8, kernel_size=5)
        #     self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        #     self.conv2 = nn.Conv2d(8, 12, kernel_size=5)
        #     self.fc1 = nn.Linear(12*4*4, 20)
        #     self.fc2 = nn.Linear(20, 10)

        # def forward(self, x):
        #     x = self.pool(self.conv1(x))
        #     x = self.pool(self.conv2(x))
        #     x = x.view(x.size(0), -1) # [N, 32 * 8 * 8]
        #     x = self.fc1(x)
        #     x = self.fc2(x)
        return x


# dataset from csv file, to use for the challenge
train_dataset = MNIST_partial(split="train")
val_dataset = MNIST_partial(split="val")

# definition of the dataloader, to process the data in the model
# here, we need a batch size of 1 to use the boson sampler
batch_size = 128
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size, shuffle=False)

# %%
learning_rate = 1e-3
num_epochs = 1


# Instantiate the model and loss function
model = CNNModel()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

num_classical_parameter = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("# of parameters in classical CNN model: ", num_classical_parameter)
# Out:
# # of parameters in classical CNN model:  978

# %%
# Training loop
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}"
            )

# %%
# Testing loop
model.eval()
correct = 0
total = 0
loss_test_list = []
with torch.no_grad():
    for images, labels in val_loader:
        outputs = model(images)
        loss_test = criterion(outputs, labels).cpu().detach().numpy()
        loss_test_list.append(loss_test)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the test set: {(100 * correct / total):.2f}%")
# Out:
# Accuracy on the test set: 51.33%

# %%
### required qubits estimation ##############
# NN weights

numpy_weights = {}
nw_list = []
nw_list_normal = []
for name, param in model.state_dict().items():
    numpy_weights[name] = param.cpu().numpy()
for i in numpy_weights:
    nw_list.append(list(numpy_weights[i].flatten()))
for i in nw_list:
    for j in i:
        nw_list_normal.append(j)
print("# of NN parameters: ", len(nw_list_normal))
n_qubits = int(np.ceil(np.log2(len(nw_list_normal))))
print("Required qubit number: ", n_qubits)

n_qubit = n_qubits

#############################################
# Out:
# # of NN parameters:  978
# Required qubit number:  10

# %%
# len(np.zeros(126)[63:])

# %%
### Some tool function definition ###########
def probs_to_weights(probs_):
    new_state_dict = {}
    data_iterator = probs_.view(-1)

    for name, param in CNNModel().state_dict().items():
        shape = param.shape
        num_elements = param.numel()
        chunk = data_iterator[:num_elements].reshape(shape)
        new_state_dict[name] = chunk
        data_iterator = data_iterator[num_elements:]

    return new_state_dict


def generate_qubit_states_torch(n_qubit):
    # Create a tensor of shape (2**n_qubit, n_qubit) with all possible combinations of 0 and 1
    all_states = torch.cartesian_prod(*[torch.tensor([-1, 1]) for _ in range(n_qubit)])
    return all_states


#############################################

### Main Learning-wise Hybridization model ##


class PhotonicQuantumTrain(nn.Module):
    class MappingModel(nn.Module):
        def __init__(self, input_size, hidden_sizes, output_size):
            super().__init__()
            # Initialize layers: an input layer, multiple hidden layers, and an output layer
            self.input_layer = nn.Linear(input_size, hidden_sizes[0])
            self.hidden_layers = nn.ModuleList(
                [
                    nn.Linear(hidden_sizes[i], hidden_sizes[i + 1])
                    for i in range(len(hidden_sizes) - 1)
                ]
            )
            self.output_layer = nn.Linear(hidden_sizes[-1], output_size)

        def forward(self, X):
            # Ensure the input tensor is the same type as the weights
            X = X.type_as(self.input_layer.weight)

            # Input layer with ReLU activation
            X = self.input_layer(X)

            # Hidden layers with ReLU activation
            for hidden in self.hidden_layers:
                X = hidden(X)

            # Output layer with linear activation
            output = self.output_layer(X)
            # output = F.tanh(output)  # It's often better to use ReLU or similar; tanh is used here as it was in the original model.
            return output

    def __init__(self):
        """ """
        super().__init__()
        self.MappingNetwork = self.MappingModel(n_qubit + 1, [8], 1).to(device)
        # self.MappingNetwork = self.ConvMappingModel()
        # self.QuantumNN = nn.parameter(135)

        # self.QLayer(q_depth).to(device)   #arch={"n_blocks": q_depth})

    def forward(self, x, qnn_parameters):
        """ """
        self.q_params_1 = qnn_parameters[
            :63
        ]  # nn.Parameter(q_delta * torch.randn(135)).to(device)
        self.q_params_2 = qnn_parameters[63:]
        device = x.device

        res_1 = bs_1.run(parameters=self.q_params_1, samples=100000)
        trans_res_1 = bs_1.translate_results(res=res_1)
        trans_res_1 = trans_res_1 / torch.mean(trans_res_1)
        probs_1 = trans_res_1.to(device)

        res_2 = bs_2.run(parameters=self.q_params_2, samples=100000)
        trans_res_2 = bs_2.translate_results(res=res_2)
        trans_res_2 = trans_res_2 / torch.mean(trans_res_2)
        probs_2 = trans_res_2.to(device)

        probs_ = torch.ger(probs_1, probs_2).flatten().reshape(35 * 35, 1)

        # probs_ = trans_res.to(device)
        probs_ = probs_[: len(nw_list_normal)]
        probs_ = probs_.reshape(len(nw_list_normal), 1)

        # Generate qubit states using PyTorch
        qubit_states_torch = generate_qubit_states_torch(n_qubit)[: len(nw_list_normal)]
        qubit_states_torch = qubit_states_torch.to(device)

        # Combine qubit states with probability values using PyTorch
        combined_data_torch = torch.cat((qubit_states_torch, probs_), dim=1)
        combined_data_torch = combined_data_torch.reshape(
            len(nw_list_normal), 1, n_qubit + 1
        )

        prob_val_post_processed = self.MappingNetwork(combined_data_torch)
        prob_val_post_processed = (
            prob_val_post_processed - prob_val_post_processed.mean()
        )

        state_dict = probs_to_weights(prob_val_post_processed)

        ########

        dtype = torch.float32  # Ensure all tensors are of this type

        # Convolution layer 1 parameters
        conv1_weight = state_dict["conv1.weight"].to(device).type(dtype)
        conv1_bias = state_dict["conv1.bias"].to(device).type(dtype)

        # Convolution layer 2 parameters
        conv2_weight = state_dict["conv2.weight"].to(device).type(dtype)
        conv2_bias = state_dict["conv2.bias"].to(device).type(dtype)

        # Fully connected layer 1 parameters
        fc1_weight = state_dict["fc1.weight"].to(device).type(dtype)
        fc1_bias = state_dict["fc1.bias"].to(device).type(dtype)

        # # Fully connected layer 2 parameters
        # fc2_weight = state_dict['fc2.weight'].to(device).type(dtype)
        # fc2_bias = state_dict['fc2.bias'].to(device).type(dtype)

        # Convolution 1
        x = F.conv2d(x, conv1_weight, conv1_bias, stride=1)
        x = F.max_pool2d(x, kernel_size=2, stride=2)

        # Convolution 2
        x = F.conv2d(x, conv2_weight, conv2_bias, stride=1)
        x = F.max_pool2d(x, kernel_size=2, stride=2)

        # Flatten
        x = x.view(x.size(0), -1)

        # Fully connected 1
        x = F.linear(x, fc1_weight, fc1_bias)

        # # Fully connected 2
        # x = F.linear(x, fc2_weight, fc2_bias)

        return x

# %%
### Training setting ########################
num_epochs = 5
step = 1e-3  # Learning rate
# batch_size = 64       # Number of samples for each training step
gamma_lr_scheduler = 0.1  # Learning rate reduction applied every 10 epochs.
q_delta = (
    2 * np.pi
)  # Phases are 2 pi periodic --> we get better expressivity by multiplying the values by 2 pi

# train_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
# train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

# test_dataset = datasets.MNIST(root='./data', train=False, transform=transform, download=True)
# test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

init_qnn_parameters = q_delta * np.random.rand(126)

qnn_parameters = init_qnn_parameters

# Instantiate the model, move it to GPU, and set up loss function and optimizer
qt_model = PhotonicQuantumTrain().to(device)
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(qt_model.parameters(), lr=step)  # , weight_decay=1e-5, eps=1e-6)
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience = 5, verbose = True, factor = 0.5)  # 'min' because we're minimizing loss

# num_trainable_params_MM = sum(p.numel() for p in PhotonicQuantumTrain.MappingModel(n_qubit+1,  [20, 4], 1).parameters() if p.requires_grad)
# num_trainable_params_MM = sum(p.numel() for p in LewHybridNN.ConvMappingModel().parameters() if p.requires_grad)
num_trainable_params = sum(p.numel() for p in qt_model.parameters() if p.requires_grad)
print("# of trainable parameter in Mapping model: ", num_trainable_params)
print(
    "# of trainable parameter in QNN model: ", bs_1.nb_parameters + bs_2.nb_parameters
)
print(
    "# of trainable parameter in full model: ",
    num_trainable_params + bs_1.nb_parameters + bs_2.nb_parameters,
)
# Out:
# # of trainable parameter in Mapping model:  105
# # of trainable parameter in QNN model:  126
# # of trainable parameter in full model:  231

# %%
# # Get a single random batch
# train_iter = iter(train_loader)  # Create an iterator
# images, labels = next(train_iter)

# print(labels)

# %%
num_training_rounds = 400
batch_size_qnn = 1000
train_loader_qnn = DataLoader(train_dataset, batch_size_qnn, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size, shuffle = False)

global images, labels

#############################################
### Training loop ###########################
#############################################

loss_list = []


for round_ in range(num_training_rounds):
    print("-----------------------")

    acc_list = []
    acc_best = 0
    for epoch in range(num_epochs):
        qt_model.train()
        train_loss = 0
        for i, (images, labels) in enumerate(train_loader):
            correct = 0
            total = 0
            since_batch = time.time()

            images, labels = images.to(device), labels.to(device)  # Move data to GPU
            optimizer.zero_grad()
            # Forward pass
            outputs = qt_model(images, qnn_parameters=qnn_parameters)
            # print("output: ", outputs)
            labels_one_hot = F.one_hot(labels, num_classes=10).float()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            # Compute loss
            loss = criterion(outputs, labels_one_hot)
            # log_loss = torch.log(loss + 1e-6)

            loss_list.append(loss.cpu().detach().numpy())
            acc = 100 * correct / total
            acc_list.append(acc)
            train_loss += loss.cpu().detach().numpy()

            # np.array(loss_list).dump("L1/3/loss_list.dat")
            # np.array(acc_list).dump("L1/3/acc_list.dat")
            if acc > acc_best:
                # torch.save(model, 'L1/3/tq_mm_acc_'+str(int(acc))+'_bsf')
                acc_best = acc
            # Backward pass and optimization
            loss.backward()

            optimizer.step()
            if (i + 1) % 20 == 0:
                print(
                    f"Training round [{round_ + 1}/{num_training_rounds}], Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}, batch time: {time.time() - since_batch:.2f}, accuracy:  {(acc):.2f}%"
                )

        train_loss /= len(train_loader)
        # scheduler.step(train_loss)

    #############################################

    num_batch_qnn = 1

    for batch_ in range(num_batch_qnn):
        # print(f"Training round [{round_+1}/{num_training_rounds}]")
        # print(f"Training round [{round_+1}/{num_training_rounds}], qnn batch {batch_ + 1}")
        global qnn_train_step
        qnn_train_step = 0

        # Get a single random batch
        train_iter = iter(train_loader_qnn)  # Create an iterator
        images, labels = next(train_iter)

        def qnn_minimize_loss(qnn_parameters_=None):
            global qnn_train_step
            global images, labels

            correct = 0
            total = 0

            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            # Forward pass
            outputs = qt_model(images, qnn_parameters=qnn_parameters_)
            labels_one_hot = F.one_hot(labels, num_classes=10).float()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            loss = criterion(outputs, labels_one_hot)
            loss = loss.cpu().detach().numpy()
            acc = 100 * correct / total
            loss_list.append(loss)

            qnn_train_step += 1
            if qnn_train_step % 100 == 0:
                # print("qnn_train_step :", qnn_train_step, ", loss :", loss, ", acc : ", acc)
                print(
                    f"Training round [{round_ + 1}/{num_training_rounds}], qnn_train_step: [{qnn_train_step}/{500}], loss: {loss}, accuracy: {acc} %"
                )

            # print("qnn_parameters [:10] :", qnn_parameters_[:10])
            return loss

        # Nelder-Mead
        # COBYLA
        # SLSQP

        init_param = qnn_parameters
        result = minimize(
            qnn_minimize_loss,
            init_param,
            method="COBYLA",
            options={"maxiter": 500, "adaptive": True},
        )

        qnn_parameters = result.x
# Out:
# -----------------------
# Training round [1/400], Epoch [1/5], Step [20/47], Loss: 192.0262, batch time: 0.02, accuracy:  14.06%
# Training round [1/400], Epoch [1/5], Step [40/47], Loss: 52.4517, batch time: 0.02, accuracy:  8.59%
# Training round [1/400], Epoch [2/5], Step [20/47], Loss: 9.2025, batch time: 0.02, accuracy:  14.84%
# Training round [1/400], Epoch [2/5], Step [40/47], Loss: 6.0321, batch time: 0.02, accuracy:  8.59%
# Training round [1/400], Epoch [3/5], Step [20/47], Loss: 4.0689, batch time: 0.02, accuracy:  21.09%
# Training round [1/400], Epoch [3/5], Step [40/47], Loss: 3.4156, batch time: 0.02, accuracy:  18.75%
# Training round [1/400], Epoch [4/5], Step [20/47], Loss: 3.2103, batch time: 0.03, accuracy:  17.19%
# Training round [1/400], Epoch [4/5], Step [40/47], Loss: 3.2108, batch time: 0.02, accuracy:  12.50%
# Training round [1/400], Epoch [5/5], Step [20/47], Loss: 3.2988, batch time: 0.02, accuracy:  14.06%
# Training round [1/400], Epoch [5/5], Step [40/47], Loss: 2.9936, batch time: 0.02, accuracy:  15.62%
# Training round [1/400], qnn_train_step: [100/500], loss: 2.747540235519409, accuracy: 19.7 %
# Training round [1/400], qnn_train_step: [200/500], loss: 2.722754955291748, accuracy: 15.2 %
# Training round [1/400], qnn_train_step: [300/500], loss: 2.63590669631958, accuracy: 20.7 %
# Training round [1/400], qnn_train_step: [400/500], loss: 2.6122066974639893, accuracy: 17.3 %
# Training round [1/400], qnn_train_step: [500/500], loss: 2.578819990158081, accuracy: 19.3 %
# -----------------------
# Training round [2/400], Epoch [1/5], Step [20/47], Loss: 2.2853, batch time: 0.02, accuracy:  25.78%
# Training round [2/400], Epoch [1/5], Step [40/47], Loss: 2.3124, batch time: 0.02, accuracy:  21.09%
# Training round [2/400], Epoch [2/5], Step [20/47], Loss: 2.3540, batch time: 0.02, accuracy:  19.53%
# Training round [2/400], Epoch [2/5], Step [40/47], Loss: 2.3646, batch time: 0.02, accuracy:  28.91%
# Training round [2/400], Epoch [3/5], Step [20/47], Loss: 2.4795, batch time: 0.02, accuracy:  17.19%
# Training round [2/400], Epoch [3/5], Step [40/47], Loss: 2.4366, batch time: 0.02, accuracy:  28.12%
# Training round [2/400], Epoch [4/5], Step [20/47], Loss: 2.5825, batch time: 0.02, accuracy:  10.94%
# Training round [2/400], Epoch [4/5], Step [40/47], Loss: 2.2965, batch time: 0.02, accuracy:  23.44%
# Training round [2/400], Epoch [5/5], Step [20/47], Loss: 2.3646, batch time: 0.02, accuracy:  17.19%
# Training round [2/400], Epoch [5/5], Step [40/47], Loss: 2.1939, batch time: 0.03, accuracy:  24.22%
# Training round [4/400], Epoch [5/5], Step [40/47], Loss: 2.2487, batch time: 0.02, accuracy:  25.78%
# Training round [4/400], qnn_train_step: [100/500], loss: 2.22275447845459, accuracy: 12.7 %
# Training round [4/400], qnn_train_step: [200/500], loss: 2.1534693241119385, accuracy: 30.9 %
# Training round [4/400], qnn_train_step: [300/500], loss: 2.166395425796509, accuracy: 25.0 %
# Training round [4/400], qnn_train_step: [400/500], loss: 2.1579959392547607, accuracy: 31.0 %
# Training round [4/400], qnn_train_step: [500/500], loss: 2.1461334228515625, accuracy: 27.5 %
# -----------------------
# Training round [5/400], Epoch [1/5], Step [20/47], Loss: 2.2132, batch time: 0.02, accuracy:  23.44%
# Training round [5/400], Epoch [1/5], Step [40/47], Loss: 2.1279, batch time: 0.02, accuracy:  22.66%
# Training round [5/400], Epoch [2/5], Step [20/47], Loss: 2.1814, batch time: 0.03, accuracy:  21.09%
# Training round [5/400], Epoch [2/5], Step [40/47], Loss: 2.1841, batch time: 0.03, accuracy:  29.69%
# Training round [5/400], Epoch [3/5], Step [20/47], Loss: 2.1651, batch time: 0.02, accuracy:  26.56%
# Training round [5/400], Epoch [3/5], Step [40/47], Loss: 2.0784, batch time: 0.02, accuracy:  30.47%
# Training round [5/400], Epoch [4/5], Step [20/47], Loss: 2.1485, batch time: 0.02, accuracy:  26.56%
# Training round [5/400], Epoch [4/5], Step [40/47], Loss: 2.2785, batch time: 0.02, accuracy:  28.12%
# Training round [5/400], Epoch [5/5], Step [20/47], Loss: 2.1567, batch time: 0.03, accuracy:  24.22%
# Training round [5/400], Epoch [5/5], Step [40/47], Loss: 2.1875, batch time: 0.02, accuracy:  25.78%
# Training round [5/400], qnn_train_step: [100/500], loss: 2.174086093902588, accuracy: 14.8 %
# Training round [5/400], qnn_train_step: [200/500], loss: 2.0855681896209717, accuracy: 31.8 %
# Training round [5/400], qnn_train_step: [300/500], loss: 2.0873589515686035, accuracy: 30.3 %
# Training round [5/400], qnn_train_step: [400/500], loss: 2.084383726119995, accuracy: 31.8 %
# Training round [5/400], qnn_train_step: [500/500], loss: 2.083416223526001, accuracy: 31.5 %
# -----------------------
# Training round [6/400], Epoch [1/5], Step [20/47], Loss: 2.1292, batch time: 0.02, accuracy:  28.12%
# Training round [6/400], Epoch [1/5], Step [40/47], Loss: 2.0837, batch time: 0.02, accuracy:  29.69%
# Training round [6/400], Epoch [2/5], Step [20/47], Loss: 2.1213, batch time: 0.02, accuracy:  29.69%
# Training round [6/400], Epoch [2/5], Step [40/47], Loss: 2.0625, batch time: 0.03, accuracy:  32.03%
# Training round [6/400], Epoch [3/5], Step [20/47], Loss: 2.0869, batch time: 0.02, accuracy:  25.78%
# Training round [6/400], Epoch [3/5], Step [40/47], Loss: 2.0668, batch time: 0.02, accuracy:  28.12%
# Training round [6/400], Epoch [4/5], Step [20/47], Loss: 2.1194, batch time: 0.02, accuracy:  28.91%
# Training round [6/400], Epoch [4/5], Step [40/47], Loss: 2.2376, batch time: 0.02, accuracy:  21.09%
# Training round [6/400], Epoch [5/5], Step [20/47], Loss: 2.0891, batch time: 0.02, accuracy:  25.00%
# Training round [6/400], Epoch [5/5], Step [40/47], Loss: 2.1282, batch time: 0.02, accuracy:  30.47%
# Training round [6/400], qnn_train_step: [100/500], loss: 2.167414665222168, accuracy: 16.2 %
# Training round [6/400], qnn_train_step: [200/500], loss: 2.098658323287964, accuracy: 26.8 %
# Training round [6/400], qnn_train_step: [300/500], loss: 2.104611396789551, accuracy: 26.5 %
# Training round [6/400], qnn_train_step: [400/500], loss: 2.1121416091918945, accuracy: 25.1 %
# Training round [6/400], qnn_train_step: [500/500], loss: 2.0986759662628174, accuracy: 21.7 %
# -----------------------
# Training round [7/400], Epoch [1/5], Step [20/47], Loss: 2.1268, batch time: 0.02, accuracy:  25.00%
# Training round [7/400], Epoch [1/5], Step [40/47], Loss: 2.0980, batch time: 0.02, accuracy:  27.34%
# Training round [7/400], Epoch [2/5], Step [20/47], Loss: 2.0439, batch time: 0.02, accuracy:  32.03%
# Training round [7/400], Epoch [2/5], Step [40/47], Loss: 2.1148, batch time: 0.02, accuracy:  25.78%
# Training round [7/400], Epoch [3/5], Step [20/47], Loss: 2.1695, batch time: 0.02, accuracy:  24.22%
# Training round [7/400], Epoch [3/5], Step [40/47], Loss: 2.1236, batch time: 0.03, accuracy:  25.78%
# Training round [7/400], Epoch [4/5], Step [20/47], Loss: 2.0480, batch time: 0.03, accuracy:  29.69%
# Training round [7/400], Epoch [4/5], Step [40/47], Loss: 2.1311, batch time: 0.02, accuracy:  27.34%
# Training round [7/400], Epoch [5/5], Step [20/47], Loss: 2.0027, batch time: 0.02, accuracy:  34.38%
# Training round [7/400], Epoch [5/5], Step [40/47], Loss: 2.0431, batch time: 0.02, accuracy:  24.22%
# Training round [7/400], qnn_train_step: [100/500], loss: 2.195718288421631, accuracy: 16.4 %
# Training round [7/400], qnn_train_step: [200/500], loss: 2.119734048843384, accuracy: 26.7 %
# Training round [7/400], qnn_train_step: [300/500], loss: 2.1281020641326904, accuracy: 26.7 %
# Training round [7/400], qnn_train_step: [400/500], loss: 2.1156601905822754, accuracy: 27.3 %
# Training round [7/400], qnn_train_step: [500/500], loss: 2.1150832176208496, accuracy: 26.0 %
# -----------------------
# Training round [8/400], Epoch [1/5], Step [20/47], Loss: 2.0276, batch time: 0.02, accuracy:  31.25%
# Training round [8/400], Epoch [1/5], Step [40/47], Loss: 2.1248, batch time: 0.02, accuracy:  20.31%
# Training round [8/400], Epoch [2/5], Step [20/47], Loss: 2.0693, batch time: 0.02, accuracy:  29.69%
# Training round [8/400], Epoch [2/5], Step [40/47], Loss: 2.0978, batch time: 0.03, accuracy:  22.66%
# Training round [8/400], Epoch [3/5], Step [20/47], Loss: 2.0135, batch time: 0.02, accuracy:  29.69%
# Training round [8/400], Epoch [3/5], Step [40/47], Loss: 1.9727, batch time: 0.02, accuracy:  33.59%
# Training round [8/400], Epoch [4/5], Step [20/47], Loss: 2.2077, batch time: 0.02, accuracy:  22.66%
# Training round [10/400], Epoch [4/5], Step [20/47], Loss: 1.9842, batch time: 0.02, accuracy:  27.34%
# Training round [10/400], Epoch [4/5], Step [40/47], Loss: 2.0687, batch time: 0.03, accuracy:  31.25%
# Training round [10/400], Epoch [5/5], Step [20/47], Loss: 2.0647, batch time: 0.02, accuracy:  25.00%
# Training round [10/400], Epoch [5/5], Step [40/47], Loss: 2.0551, batch time: 0.02, accuracy:  27.34%
# Training round [10/400], qnn_train_step: [100/500], loss: 2.140738010406494, accuracy: 17.6 %
# Training round [10/400], qnn_train_step: [200/500], loss: 2.036806344985962, accuracy: 26.7 %
# Training round [10/400], qnn_train_step: [300/500], loss: 2.037055730819702, accuracy: 28.4 %
# Training round [10/400], qnn_train_step: [400/500], loss: 2.0347321033477783, accuracy: 30.2 %
# Training round [10/400], qnn_train_step: [500/500], loss: 2.0315911769866943, accuracy: 28.3 %
# -----------------------
# Training round [11/400], Epoch [1/5], Step [20/47], Loss: 2.0404, batch time: 0.03, accuracy:  25.00%
# Training round [11/400], Epoch [1/5], Step [40/47], Loss: 1.9729, batch time: 0.02, accuracy:  32.81%
# Training round [11/400], Epoch [2/5], Step [20/47], Loss: 2.1079, batch time: 0.02, accuracy:  25.78%
# Training round [11/400], Epoch [2/5], Step [40/47], Loss: 2.0768, batch time: 0.02, accuracy:  25.78%
# Training round [11/400], Epoch [3/5], Step [20/47], Loss: 1.9869, batch time: 0.02, accuracy:  30.47%
# Training round [11/400], Epoch [3/5], Step [40/47], Loss: 2.0363, batch time: 0.03, accuracy:  21.88%
# Training round [11/400], Epoch [4/5], Step [20/47], Loss: 2.0783, batch time: 0.02, accuracy:  29.69%
# Training round [11/400], Epoch [4/5], Step [40/47], Loss: 1.9518, batch time: 0.02, accuracy:  31.25%
# Training round [11/400], Epoch [5/5], Step [20/47], Loss: 2.0578, batch time: 0.02, accuracy:  23.44%
# Training round [11/400], Epoch [5/5], Step [40/47], Loss: 2.0537, batch time: 0.02, accuracy:  28.12%
# Training round [11/400], qnn_train_step: [100/500], loss: 2.1237287521362305, accuracy: 18.3 %
# Training round [11/400], qnn_train_step: [200/500], loss: 2.06947660446167, accuracy: 21.3 %
# Training round [11/400], qnn_train_step: [300/500], loss: 2.043422222137451, accuracy: 26.1 %
# Training round [11/400], qnn_train_step: [400/500], loss: 2.038078546524048, accuracy: 23.3 %
# Training round [11/400], qnn_train_step: [500/500], loss: 2.0616657733917236, accuracy: 24.2 %
# -----------------------
# Training round [12/400], Epoch [1/5], Step [20/47], Loss: 2.0018, batch time: 0.06, accuracy:  28.91%
# Training round [12/400], Epoch [1/5], Step [40/47], Loss: 1.9117, batch time: 0.02, accuracy:  28.91%
# Training round [12/400], Epoch [2/5], Step [20/47], Loss: 2.1460, batch time: 0.03, accuracy:  21.88%
# Training round [12/400], Epoch [2/5], Step [40/47], Loss: 2.0619, batch time: 0.02, accuracy:  26.56%
# Training round [12/400], Epoch [3/5], Step [20/47], Loss: 2.0459, batch time: 0.02, accuracy:  24.22%
# Training round [18/400], Epoch [1/5], Step [40/47], Loss: 1.9467, batch time: 0.02, accuracy:  32.03%
# Training round [18/400], Epoch [2/5], Step [20/47], Loss: 1.9683, batch time: 0.06, accuracy:  35.94%
# Training round [18/400], Epoch [2/5], Step [40/47], Loss: 1.9224, batch time: 0.02, accuracy:  37.50%
# Training round [18/400], Epoch [3/5], Step [20/47], Loss: 1.9298, batch time: 0.03, accuracy:  34.38%
# Training round [18/400], Epoch [3/5], Step [40/47], Loss: 2.0252, batch time: 0.02, accuracy:  32.81%
# Training round [18/400], Epoch [4/5], Step [20/47], Loss: 2.0239, batch time: 0.02, accuracy:  32.03%
# Training round [18/400], Epoch [4/5], Step [40/47], Loss: 2.0465, batch time: 0.02, accuracy:  33.59%
# Training round [18/400], Epoch [5/5], Step [20/47], Loss: 1.9142, batch time: 0.02, accuracy:  32.81%
# Training round [18/400], Epoch [5/5], Step [40/47], Loss: 1.9930, batch time: 0.02, accuracy:  33.59%
# Training round [18/400], qnn_train_step: [100/500], loss: 2.198319911956787, accuracy: 18.0 %
# Training round [18/400], qnn_train_step: [200/500], loss: 2.0190227031707764, accuracy: 24.3 %
# Training round [18/400], qnn_train_step: [300/500], loss: 2.010981559753418, accuracy: 22.7 %
# Training round [18/400], qnn_train_step: [400/500], loss: 1.958711862564087, accuracy: 30.1 %
# Training round [18/400], qnn_train_step: [500/500], loss: 1.9523591995239258, accuracy: 30.0 %
# -----------------------
# Training round [19/400], Epoch [1/5], Step [20/47], Loss: 1.8353, batch time: 0.02, accuracy:  35.94%
# Training round [19/400], Epoch [1/5], Step [40/47], Loss: 2.0163, batch time: 0.02, accuracy:  28.91%
# Training round [19/400], Epoch [2/5], Step [20/47], Loss: 1.9702, batch time: 0.02, accuracy:  31.25%
# Training round [19/400], Epoch [2/5], Step [40/47], Loss: 1.8885, batch time: 0.02, accuracy:  32.81%
# Training round [19/400], Epoch [3/5], Step [20/47], Loss: 2.0445, batch time: 0.06, accuracy:  32.03%
# Training round [19/400], Epoch [3/5], Step [40/47], Loss: 1.9638, batch time: 0.03, accuracy:  30.47%
# Training round [19/400], Epoch [4/5], Step [20/47], Loss: 1.9429, batch time: 0.06, accuracy:  32.03%
# Training round [19/400], Epoch [4/5], Step [40/47], Loss: 1.9850, batch time: 0.03, accuracy:  32.81%
# Training round [19/400], Epoch [5/5], Step [20/47], Loss: 1.9514, batch time: 0.05, accuracy:  32.81%
# Training round [19/400], Epoch [5/5], Step [40/47], Loss: 2.0049, batch time: 0.03, accuracy:  30.47%
# Training round [19/400], qnn_train_step: [100/500], loss: 2.2462308406829834, accuracy: 17.0 %
# Training round [19/400], qnn_train_step: [200/500], loss: 1.9809460639953613, accuracy: 30.6 %
# Training round [19/400], qnn_train_step: [300/500], loss: 2.1576216220855713, accuracy: 20.5 %
# Training round [19/400], qnn_train_step: [400/500], loss: 1.9590307474136353, accuracy: 30.3 %
# Training round [19/400], qnn_train_step: [500/500], loss: 1.952592372894287, accuracy: 33.5 %
# -----------------------
# Training round [20/400], Epoch [1/5], Step [20/47], Loss: 1.9288, batch time: 0.02, accuracy:  37.50%
# Training round [20/400], Epoch [1/5], Step [40/47], Loss: 2.0266, batch time: 0.02, accuracy:  31.25%
# Training round [20/400], Epoch [2/5], Step [20/47], Loss: 1.9737, batch time: 0.02, accuracy:  31.25%
# Training round [20/400], Epoch [2/5], Step [40/47], Loss: 1.9469, batch time: 0.02, accuracy:  31.25%
# Training round [20/400], Epoch [3/5], Step [20/47], Loss: 2.0105, batch time: 0.02, accuracy:  34.38%
# Training round [20/400], Epoch [3/5], Step [40/47], Loss: 1.8246, batch time: 0.02, accuracy:  36.72%
# Training round [20/400], Epoch [4/5], Step [20/47], Loss: 2.0642, batch time: 0.02, accuracy:  27.34%
# Training round [20/400], Epoch [4/5], Step [40/47], Loss: 1.9690, batch time: 0.02, accuracy:  35.94%
# Training round [20/400], Epoch [5/5], Step [20/47], Loss: 1.8862, batch time: 0.03, accuracy:  25.78%
# Training round [20/400], Epoch [5/5], Step [40/47], Loss: 2.0206, batch time: 0.03, accuracy:  31.25%
# Training round [20/400], qnn_train_step: [100/500], loss: 2.213374137878418, accuracy: 23.0 %
# Training round [20/400], qnn_train_step: [200/500], loss: 1.9860962629318237, accuracy: 27.8 %
# Training round [20/400], qnn_train_step: [300/500], loss: 1.901528000831604, accuracy: 33.3 %
# Training round [20/400], qnn_train_step: [400/500], loss: 1.8992630243301392, accuracy: 33.1 %
# Training round [20/400], qnn_train_step: [500/500], loss: 1.903211236000061, accuracy: 32.0 %
# -----------------------
# Training round [21/400], Epoch [1/5], Step [20/47], Loss: 2.0260, batch time: 0.02, accuracy:  30.47%
# Training round [21/400], Epoch [1/5], Step [40/47], Loss: 1.9064, batch time: 0.02, accuracy:  33.59%
# Training round [21/400], Epoch [2/5], Step [20/47], Loss: 1.9959, batch time: 0.02, accuracy:  34.38%
# Training round [21/400], Epoch [2/5], Step [40/47], Loss: 1.7931, batch time: 0.02, accuracy:  36.72%
# Training round [21/400], Epoch [3/5], Step [20/47], Loss: 1.8751, batch time: 0.02, accuracy:  36.72%
# Training round [21/400], Epoch [3/5], Step [40/47], Loss: 1.8673, batch time: 0.02, accuracy:  32.81%
# Training round [21/400], Epoch [4/5], Step [20/47], Loss: 1.8857, batch time: 0.06, accuracy:  28.12%
# Training round [21/400], Epoch [4/5], Step [40/47], Loss: 2.0522, batch time: 0.06, accuracy:  28.91%
# Training round [21/400], Epoch [5/5], Step [20/47], Loss: 1.8449, batch time: 0.06, accuracy:  33.59%
# Training round [21/400], Epoch [5/5], Step [40/47], Loss: 2.0464, batch time: 0.06, accuracy:  25.78%
# Training round [21/400], qnn_train_step: [100/500], loss: 2.376175880432129, accuracy: 14.6 %
# Training round [21/400], qnn_train_step: [200/500], loss: 1.909498691558838, accuracy: 33.9 %
# Training round [21/400], qnn_train_step: [300/500], loss: 1.9613101482391357, accuracy: 29.6 %
# Training round [21/400], qnn_train_step: [400/500], loss: 1.8986846208572388, accuracy: 33.5 %
# Training round [23/400], qnn_train_step: [400/500], loss: 1.8282878398895264, accuracy: 38.5 %
# Training round [23/400], qnn_train_step: [500/500], loss: 1.8252073526382446, accuracy: 38.3 %
# -----------------------
# Training round [24/400], Epoch [1/5], Step [20/47], Loss: 1.8668, batch time: 0.03, accuracy:  36.72%
# Training round [24/400], Epoch [1/5], Step [40/47], Loss: 2.0522, batch time: 0.06, accuracy:  39.06%
# Training round [24/400], Epoch [2/5], Step [20/47], Loss: 1.8936, batch time: 0.06, accuracy:  39.84%
# Training round [24/400], Epoch [2/5], Step [40/47], Loss: 1.9104, batch time: 0.06, accuracy:  35.94%
# Training round [24/400], Epoch [3/5], Step [20/47], Loss: 1.9879, batch time: 0.02, accuracy:  38.28%
# Training round [24/400], Epoch [3/5], Step [40/47], Loss: 1.7111, batch time: 0.06, accuracy:  40.62%
# Training round [24/400], Epoch [4/5], Step [20/47], Loss: 1.8632, batch time: 0.06, accuracy:  36.72%
# Training round [24/400], Epoch [4/5], Step [40/47], Loss: 1.8422, batch time: 0.02, accuracy:  30.47%
# Training round [24/400], Epoch [5/5], Step [20/47], Loss: 1.8429, batch time: 0.02, accuracy:  37.50%
# Training round [24/400], Epoch [5/5], Step [40/47], Loss: 1.8223, batch time: 0.06, accuracy:  43.75%
# Training round [24/400], qnn_train_step: [100/500], loss: 3.0847604274749756, accuracy: 19.0 %
# Training round [24/400], qnn_train_step: [200/500], loss: 1.9100970029830933, accuracy: 35.9 %
# Training round [24/400], qnn_train_step: [300/500], loss: 1.8521355390548706, accuracy: 38.9 %
# Training round [24/400], qnn_train_step: [400/500], loss: 1.8448621034622192, accuracy: 37.7 %
# Training round [24/400], qnn_train_step: [500/500], loss: 1.8435741662979126, accuracy: 39.7 %
# -----------------------
# Training round [25/400], Epoch [1/5], Step [20/47], Loss: 1.7733, batch time: 0.03, accuracy:  50.00%
# Training round [25/400], Epoch [1/5], Step [40/47], Loss: 1.8077, batch time: 0.06, accuracy:  40.62%
# Training round [25/400], Epoch [2/5], Step [20/47], Loss: 1.9989, batch time: 0.06, accuracy:  30.47%
# Training round [25/400], Epoch [2/5], Step [40/47], Loss: 1.7161, batch time: 0.02, accuracy:  47.66%
# Training round [25/400], Epoch [3/5], Step [20/47], Loss: 1.8974, batch time: 0.02, accuracy:  31.25%
# Training round [25/400], Epoch [3/5], Step [40/47], Loss: 1.8484, batch time: 0.03, accuracy:  35.16%
# Training round [25/400], Epoch [4/5], Step [20/47], Loss: 1.8343, batch time: 0.03, accuracy:  44.53%
# Training round [25/400], Epoch [4/5], Step [40/47], Loss: 1.7994, batch time: 0.02, accuracy:  40.62%
# Training round [25/400], Epoch [5/5], Step [20/47], Loss: 1.7471, batch time: 0.02, accuracy:  44.53%
# Training round [25/400], Epoch [5/5], Step [40/47], Loss: 1.8062, batch time: 0.02, accuracy:  42.19%
# Training round [25/400], qnn_train_step: [100/500], loss: 3.1970107555389404, accuracy: 17.2 %
# Training round [25/400], qnn_train_step: [200/500], loss: 1.8926076889038086, accuracy: 35.7 %
# Training round [25/400], qnn_train_step: [300/500], loss: 1.7777690887451172, accuracy: 37.7 %
# Training round [25/400], qnn_train_step: [400/500], loss: 1.7593328952789307, accuracy: 43.3 %
# Training round [25/400], qnn_train_step: [500/500], loss: 1.752759337425232, accuracy: 44.3 %
# -----------------------
# Training round [26/400], Epoch [1/5], Step [20/47], Loss: 1.6615, batch time: 0.02, accuracy:  46.88%
# Training round [26/400], Epoch [1/5], Step [40/47], Loss: 1.7168, batch time: 0.02, accuracy:  41.41%
# Training round [26/400], Epoch [2/5], Step [20/47], Loss: 1.8016, batch time: 0.06, accuracy:  38.28%
# Training round [26/400], Epoch [2/5], Step [40/47], Loss: 1.9465, batch time: 0.03, accuracy:  36.72%
# Training round [26/400], Epoch [3/5], Step [20/47], Loss: 1.8269, batch time: 0.06, accuracy:  35.16%
# Training round [26/400], Epoch [3/5], Step [40/47], Loss: 1.7618, batch time: 0.06, accuracy:  42.19%
# Training round [26/400], Epoch [4/5], Step [20/47], Loss: 1.8428, batch time: 0.06, accuracy:  42.19%
# Training round [26/400], Epoch [4/5], Step [40/47], Loss: 1.8622, batch time: 0.02, accuracy:  36.72%
# Training round [26/400], Epoch [5/5], Step [20/47], Loss: 1.7077, batch time: 0.02, accuracy:  46.09%
# Training round [26/400], Epoch [5/5], Step [40/47], Loss: 1.8815, batch time: 0.02, accuracy:  34.38%
# Training round [26/400], qnn_train_step: [100/500], loss: 3.115922689437866, accuracy: 17.4 %
# Training round [26/400], qnn_train_step: [200/500], loss: 2.7832305431365967, accuracy: 13.9 %
# Training round [26/400], qnn_train_step: [300/500], loss: 1.7930246591567993, accuracy: 42.1 %
# Training round [26/400], qnn_train_step: [400/500], loss: 1.7844901084899902, accuracy: 39.8 %
# Training round [26/400], qnn_train_step: [500/500], loss: 1.8060379028320312, accuracy: 38.4 %
# -----------------------
# Training round [27/400], Epoch [1/5], Step [20/47], Loss: 1.7680, batch time: 0.03, accuracy:  44.53%
# Training round [27/400], Epoch [1/5], Step [40/47], Loss: 1.7959, batch time: 0.02, accuracy:  46.09%
# Training round [27/400], Epoch [2/5], Step [20/47], Loss: 1.7827, batch time: 0.02, accuracy:  47.66%
# Training round [27/400], Epoch [2/5], Step [40/47], Loss: 1.7233, batch time: 0.02, accuracy:  39.84%
# Training round [27/400], Epoch [3/5], Step [20/47], Loss: 1.8202, batch time: 0.02, accuracy:  40.62%
# Training round [27/400], Epoch [3/5], Step [40/47], Loss: 1.7114, batch time: 0.03, accuracy:  40.62%
# Training round [27/400], Epoch [4/5], Step [20/47], Loss: 1.6379, batch time: 0.02, accuracy:  44.53%
# Training round [27/400], Epoch [4/5], Step [40/47], Loss: 1.8675, batch time: 0.02, accuracy:  41.41%
# Training round [27/400], Epoch [5/5], Step [20/47], Loss: 1.8221, batch time: 0.02, accuracy:  42.19%
# Training round [27/400], Epoch [5/5], Step [40/47], Loss: 1.5830, batch time: 0.02, accuracy:  48.44%
# Training round [27/400], qnn_train_step: [100/500], loss: 2.8968873023986816, accuracy: 22.2 %
# Training round [27/400], qnn_train_step: [200/500], loss: 1.9676507711410522, accuracy: 34.7 %
# Training round [27/400], qnn_train_step: [300/500], loss: 1.7687519788742065, accuracy: 44.0 %
# Training round [27/400], qnn_train_step: [400/500], loss: 1.750933051109314, accuracy: 44.9 %
# Training round [27/400], qnn_train_step: [500/500], loss: 1.7620466947555542, accuracy: 44.4 %
# -----------------------
# Training round [28/400], Epoch [1/5], Step [20/47], Loss: 1.6551, batch time: 0.03, accuracy:  48.44%
# Training round [28/400], Epoch [1/5], Step [40/47], Loss: 1.5804, batch time: 0.04, accuracy:  46.88%
# Training round [28/400], Epoch [2/5], Step [20/47], Loss: 1.7450, batch time: 0.02, accuracy:  36.72%
# Training round [28/400], Epoch [2/5], Step [40/47], Loss: 1.7520, batch time: 0.02, accuracy:  43.75%
# Training round [28/400], Epoch [3/5], Step [20/47], Loss: 1.7198, batch time: 0.02, accuracy:  42.19%
# Training round [28/400], Epoch [3/5], Step [40/47], Loss: 1.8942, batch time: 0.03, accuracy:  42.97%
# Training round [28/400], Epoch [4/5], Step [20/47], Loss: 1.6111, batch time: 0.02, accuracy:  45.31%
# Training round [28/400], Epoch [4/5], Step [40/47], Loss: 1.9612, batch time: 0.03, accuracy:  35.94%
# Training round [28/400], Epoch [5/5], Step [20/47], Loss: 1.7318, batch time: 0.02, accuracy:  39.84%
# Training round [28/400], Epoch [5/5], Step [40/47], Loss: 1.6792, batch time: 0.02, accuracy:  46.88%
# Training round [28/400], qnn_train_step: [100/500], loss: 2.984051465988159, accuracy: 23.9 %
# Training round [28/400], qnn_train_step: [200/500], loss: 1.7864834070205688, accuracy: 40.9 %
# Training round [28/400], qnn_train_step: [300/500], loss: 1.7527275085449219, accuracy: 43.8 %
# Training round [28/400], qnn_train_step: [400/500], loss: 1.7644758224487305, accuracy: 42.0 %
# Training round [28/400], qnn_train_step: [500/500], loss: 1.748276710510254, accuracy: 43.2 %
# -----------------------
# Training round [29/400], Epoch [1/5], Step [20/47], Loss: 1.7424, batch time: 0.06, accuracy:  42.19%
# Training round [29/400], Epoch [1/5], Step [40/47], Loss: 1.5630, batch time: 0.06, accuracy:  50.00%
# Training round [29/400], Epoch [2/5], Step [20/47], Loss: 1.7395, batch time: 0.03, accuracy:  38.28%
# Training round [29/400], Epoch [2/5], Step [40/47], Loss: 1.7009, batch time: 0.06, accuracy:  48.44%
# Training round [29/400], Epoch [3/5], Step [20/47], Loss: 1.7045, batch time: 0.06, accuracy:  42.97%
# Training round [29/400], Epoch [3/5], Step [40/47], Loss: 1.6824, batch time: 0.06, accuracy:  46.09%
# Training round [29/400], Epoch [4/5], Step [20/47], Loss: 1.7869, batch time: 0.06, accuracy:  34.38%
# Training round [29/400], Epoch [4/5], Step [40/47], Loss: 1.7808, batch time: 0.06, accuracy:  40.62%
# Training round [29/400], Epoch [5/5], Step [20/47], Loss: 1.6856, batch time: 0.06, accuracy:  51.56%
# Training round [31/400], Epoch [5/5], Step [20/47], Loss: 1.7219, batch time: 0.06, accuracy:  40.62%
# Training round [31/400], Epoch [5/5], Step [40/47], Loss: 1.8207, batch time: 0.06, accuracy:  45.31%
# Training round [31/400], qnn_train_step: [100/500], loss: 2.8449132442474365, accuracy: 27.5 %
# Training round [31/400], qnn_train_step: [200/500], loss: 1.7225042581558228, accuracy: 43.3 %
# Training round [31/400], qnn_train_step: [300/500], loss: 1.9057759046554565, accuracy: 36.3 %
# Training round [31/400], qnn_train_step: [400/500], loss: 1.8028196096420288, accuracy: 38.6 %
# Training round [31/400], qnn_train_step: [500/500], loss: 1.7111021280288696, accuracy: 42.7 %
# -----------------------
# Training round [32/400], Epoch [1/5], Step [20/47], Loss: 1.6620, batch time: 0.02, accuracy:  48.44%
# Training round [32/400], Epoch [1/5], Step [40/47], Loss: 1.6435, batch time: 0.02, accuracy:  41.41%
# Training round [32/400], Epoch [2/5], Step [20/47], Loss: 1.7721, batch time: 0.03, accuracy:  42.19%
# Training round [32/400], Epoch [2/5], Step [40/47], Loss: 1.8464, batch time: 0.02, accuracy:  39.06%
# Training round [32/400], Epoch [3/5], Step [20/47], Loss: 1.7189, batch time: 0.03, accuracy:  40.62%
# Training round [32/400], Epoch [3/5], Step [40/47], Loss: 1.6428, batch time: 0.02, accuracy:  52.34%
# Training round [32/400], Epoch [4/5], Step [20/47], Loss: 1.8141, batch time: 0.02, accuracy:  40.62%
# Training round [32/400], Epoch [4/5], Step [40/47], Loss: 1.6595, batch time: 0.02, accuracy:  43.75%
# Training round [32/400], Epoch [5/5], Step [20/47], Loss: 1.6620, batch time: 0.02, accuracy:  46.09%
# Training round [32/400], Epoch [5/5], Step [40/47], Loss: 1.8516, batch time: 0.03, accuracy:  36.72%
# ...
# Training round [390/400], Epoch [5/5], Step [40/47], Loss: 1.1911, batch time: 0.03, accuracy:  58.59%
# Training round [390/400], qnn_train_step: [100/500], loss: 10.86375904083252, accuracy: 16.9 %
# Training round [390/400], qnn_train_step: [200/500], loss: 2.9320831298828125, accuracy: 18.1 %
# Training round [390/400], qnn_train_step: [300/500], loss: 1.5265120267868042, accuracy: 47.1 %
# Training round [390/400], qnn_train_step: [400/500], loss: 1.6662473678588867, accuracy: 42.2 %
# Training round [390/400], qnn_train_step: [500/500], loss: 1.4252300262451172, accuracy: 52.9 %
# -----------------------
# Training round [391/400], Epoch [1/5], Step [20/47], Loss: 1.3928, batch time: 0.03, accuracy:  54.69%
# Training round [391/400], Epoch [1/5], Step [40/47], Loss: 1.3748, batch time: 0.03, accuracy:  52.34%
# Training round [391/400], Epoch [2/5], Step [20/47], Loss: 1.5050, batch time: 0.03, accuracy:  43.75%
# Training round [391/400], Epoch [2/5], Step [40/47], Loss: 1.5557, batch time: 0.03, accuracy:  42.19%
# Training round [391/400], Epoch [3/5], Step [20/47], Loss: 1.3417, batch time: 0.03, accuracy:  56.25%
# Training round [391/400], Epoch [3/5], Step [40/47], Loss: 1.3824, batch time: 0.03, accuracy:  57.03%
# Training round [391/400], Epoch [4/5], Step [20/47], Loss: 1.6622, batch time: 0.03, accuracy:  45.31%
# Training round [391/400], Epoch [4/5], Step [40/47], Loss: 1.3920, batch time: 0.03, accuracy:  56.25%
# Training round [391/400], Epoch [5/5], Step [20/47], Loss: 1.3563, batch time: 0.03, accuracy:  56.25%
# Training round [391/400], Epoch [5/5], Step [40/47], Loss: 1.4465, batch time: 0.03, accuracy:  50.00%
# Training round [391/400], qnn_train_step: [100/500], loss: 11.703192710876465, accuracy: 16.0 %
# Training round [391/400], qnn_train_step: [200/500], loss: 2.8132266998291016, accuracy: 19.0 %
# Training round [391/400], qnn_train_step: [300/500], loss: 1.386554479598999, accuracy: 51.7 %
# Training round [391/400], qnn_train_step: [400/500], loss: 1.373977780342102, accuracy: 52.0 %
# Training round [391/400], qnn_train_step: [500/500], loss: 1.371126651763916, accuracy: 53.4 %
# -----------------------
# Training round [392/400], Epoch [1/5], Step [20/47], Loss: 1.4503, batch time: 0.06, accuracy:  52.34%
# Training round [392/400], Epoch [1/5], Step [40/47], Loss: 1.4762, batch time: 0.06, accuracy:  49.22%
# Training round [392/400], Epoch [2/5], Step [20/47], Loss: 1.4907, batch time: 0.04, accuracy:  48.44%
# Training round [392/400], Epoch [2/5], Step [40/47], Loss: 1.4574, batch time: 0.03, accuracy:  57.03%
# Training round [392/400], Epoch [3/5], Step [20/47], Loss: 1.2898, batch time: 0.06, accuracy:  53.91%
# Training round [392/400], Epoch [3/5], Step [40/47], Loss: 1.1970, batch time: 0.03, accuracy:  55.47%
# Training round [392/400], Epoch [4/5], Step [20/47], Loss: 1.5196, batch time: 0.06, accuracy:  45.31%
# Training round [392/400], Epoch [4/5], Step [40/47], Loss: 1.4627, batch time: 0.03, accuracy:  53.91%
# Training round [392/400], Epoch [5/5], Step [20/47], Loss: 1.5010, batch time: 0.03, accuracy:  49.22%
# Training round [392/400], Epoch [5/5], Step [40/47], Loss: 1.4171, batch time: 0.03, accuracy:  48.44%
# Training round [392/400], qnn_train_step: [100/500], loss: 12.280535697937012, accuracy: 15.0 %
# Training round [392/400], qnn_train_step: [200/500], loss: 2.72495174407959, accuracy: 19.6 %
# Training round [392/400], qnn_train_step: [300/500], loss: 1.4091006517410278, accuracy: 50.6 %
# Training round [392/400], qnn_train_step: [400/500], loss: 1.3954523801803589, accuracy: 52.9 %
# Training round [392/400], qnn_train_step: [500/500], loss: 1.4050670862197876, accuracy: 51.1 %
# -----------------------
# Training round [393/400], Epoch [1/5], Step [20/47], Loss: 1.3719, batch time: 0.06, accuracy:  51.56%
# Training round [393/400], Epoch [1/5], Step [40/47], Loss: 1.5747, batch time: 0.06, accuracy:  50.00%
# Training round [393/400], Epoch [2/5], Step [20/47], Loss: 1.5346, batch time: 0.06, accuracy:  53.12%
# Training round [393/400], Epoch [2/5], Step [40/47], Loss: 1.4534, batch time: 0.06, accuracy:  53.91%
# Training round [393/400], Epoch [3/5], Step [20/47], Loss: 1.6158, batch time: 0.03, accuracy:  43.75%
# Training round [393/400], Epoch [3/5], Step [40/47], Loss: 1.1864, batch time: 0.06, accuracy:  66.41%
# Training round [393/400], Epoch [4/5], Step [20/47], Loss: 1.4456, batch time: 0.05, accuracy:  49.22%
# Training round [393/400], Epoch [4/5], Step [40/47], Loss: 1.4482, batch time: 0.03, accuracy:  49.22%
# Training round [393/400], Epoch [5/5], Step [20/47], Loss: 1.2888, batch time: 0.03, accuracy:  57.81%
# Training round [393/400], Epoch [5/5], Step [40/47], Loss: 1.4328, batch time: 0.06, accuracy:  51.56%
# Training round [393/400], qnn_train_step: [100/500], loss: 12.57292366027832, accuracy: 14.4 %
# Training round [393/400], qnn_train_step: [200/500], loss: 1.8856056928634644, accuracy: 37.3 %
# Training round [393/400], qnn_train_step: [300/500], loss: 1.4730242490768433, accuracy: 47.0 %
# Training round [393/400], qnn_train_step: [400/500], loss: 1.7633130550384521, accuracy: 41.6 %
# Training round [393/400], qnn_train_step: [500/500], loss: 1.4179942607879639, accuracy: 52.5 %
# -----------------------
# Training round [394/400], Epoch [1/5], Step [20/47], Loss: 1.5433, batch time: 0.03, accuracy:  45.31%
# Training round [394/400], Epoch [1/5], Step [40/47], Loss: 1.4147, batch time: 0.03, accuracy:  49.22%
# Training round [394/400], Epoch [2/5], Step [20/47], Loss: 1.5058, batch time: 0.06, accuracy:  50.78%
# Training round [394/400], Epoch [2/5], Step [40/47], Loss: 1.3686, batch time: 0.06, accuracy:  57.81%
# Training round [394/400], Epoch [3/5], Step [20/47], Loss: 1.4291, batch time: 0.03, accuracy:  53.12%
# Training round [394/400], Epoch [3/5], Step [40/47], Loss: 1.4300, batch time: 0.03, accuracy:  48.44%
# Training round [394/400], Epoch [4/5], Step [20/47], Loss: 1.2833, batch time: 0.05, accuracy:  54.69%
# Training round [394/400], Epoch [4/5], Step [40/47], Loss: 1.4947, batch time: 0.06, accuracy:  45.31%
# Training round [394/400], Epoch [5/5], Step [20/47], Loss: 1.3480, batch time: 0.06, accuracy:  53.91%
# Training round [394/400], Epoch [5/5], Step [40/47], Loss: 1.2685, batch time: 0.03, accuracy:  51.56%
# Training round [394/400], qnn_train_step: [100/500], loss: 11.827101707458496, accuracy: 15.4 %
# Training round [394/400], qnn_train_step: [200/500], loss: 2.93515944480896, accuracy: 16.9 %
# Training round [394/400], qnn_train_step: [300/500], loss: 1.5027540922164917, accuracy: 50.3 %
# Training round [394/400], qnn_train_step: [400/500], loss: 1.4996637105941772, accuracy: 48.2 %
# Training round [394/400], qnn_train_step: [500/500], loss: 1.480004906654358, accuracy: 51.5 %
# -----------------------
# Training round [395/400], Epoch [1/5], Step [20/47], Loss: 1.5369, batch time: 0.03, accuracy:  44.53%
# Training round [395/400], Epoch [1/5], Step [40/47], Loss: 1.3951, batch time: 0.03, accuracy:  57.81%
# Training round [395/400], Epoch [2/5], Step [20/47], Loss: 1.8171, batch time: 0.06, accuracy:  41.41%
# Training round [395/400], Epoch [2/5], Step [40/47], Loss: 1.4494, batch time: 0.06, accuracy:  53.12%
# Training round [395/400], Epoch [3/5], Step [20/47], Loss: 1.4415, batch time: 0.06, accuracy:  52.34%
# Training round [395/400], Epoch [3/5], Step [40/47], Loss: 1.4599, batch time: 0.06, accuracy:  54.69%
# Training round [395/400], Epoch [4/5], Step [20/47], Loss: 1.4111, batch time: 0.06, accuracy:  51.56%
# Training round [395/400], Epoch [4/5], Step [40/47], Loss: 1.2943, batch time: 0.06, accuracy:  57.81%
# Training round [395/400], Epoch [5/5], Step [20/47], Loss: 1.3486, batch time: 0.06, accuracy:  50.00%
# Training round [395/400], Epoch [5/5], Step [40/47], Loss: 1.5131, batch time: 0.06, accuracy:  44.53%
# Training round [395/400], qnn_train_step: [100/500], loss: 12.444119453430176, accuracy: 17.9 %
# Training round [395/400], qnn_train_step: [200/500], loss: 1.7410310506820679, accuracy: 44.7 %
# Training round [395/400], qnn_train_step: [300/500], loss: 1.3868924379348755, accuracy: 55.4 %
# Training round [395/400], qnn_train_step: [400/500], loss: 1.3789927959442139, accuracy: 54.8 %
# Training round [395/400], qnn_train_step: [500/500], loss: 1.495466947555542, accuracy: 48.2 %
# -----------------------
# Training round [396/400], Epoch [1/5], Step [20/47], Loss: 1.5658, batch time: 0.03, accuracy:  46.88%
# Training round [396/400], Epoch [1/5], Step [40/47], Loss: 1.4548, batch time: 0.03, accuracy:  57.81%
# Training round [396/400], Epoch [2/5], Step [20/47], Loss: 1.3990, batch time: 0.07, accuracy:  57.03%
# Training round [396/400], Epoch [2/5], Step [40/47], Loss: 1.4695, batch time: 0.06, accuracy:  52.34%
# Training round [396/400], Epoch [3/5], Step [20/47], Loss: 1.4419, batch time: 0.06, accuracy:  57.81%
# Training round [396/400], Epoch [3/5], Step [40/47], Loss: 1.3299, batch time: 0.06, accuracy:  58.59%
# Training round [396/400], Epoch [4/5], Step [20/47], Loss: 1.4237, batch time: 0.06, accuracy:  56.25%
# Training round [396/400], Epoch [4/5], Step [40/47], Loss: 1.3080, batch time: 0.06, accuracy:  55.47%
# Training round [396/400], Epoch [5/5], Step [20/47], Loss: 1.2848, batch time: 0.03, accuracy:  58.59%
# Training round [396/400], Epoch [5/5], Step [40/47], Loss: 1.3829, batch time: 0.03, accuracy:  54.69%
# Training round [396/400], qnn_train_step: [100/500], loss: 11.575543403625488, accuracy: 17.8 %
# Training round [396/400], qnn_train_step: [200/500], loss: 1.4408267736434937, accuracy: 51.5 %
# Training round [396/400], qnn_train_step: [300/500], loss: 1.4058644771575928, accuracy: 53.2 %
# Training round [396/400], qnn_train_step: [400/500], loss: 1.4092515707015991, accuracy: 53.9 %
# Training round [396/400], qnn_train_step: [500/500], loss: 1.401103138923645, accuracy: 53.7 %
# -----------------------
# Training round [397/400], Epoch [1/5], Step [20/47], Loss: 1.4207, batch time: 0.03, accuracy:  55.47%
# Training round [397/400], Epoch [1/5], Step [40/47], Loss: 1.7270, batch time: 0.03, accuracy:  50.78%
# Training round [397/400], Epoch [2/5], Step [20/47], Loss: 1.4637, batch time: 0.03, accuracy:  57.81%
# Training round [397/400], Epoch [2/5], Step [40/47], Loss: 1.4088, batch time: 0.03, accuracy:  57.03%
# Training round [397/400], Epoch [3/5], Step [20/47], Loss: 1.4805, batch time: 0.06, accuracy:  50.78%
# Training round [397/400], Epoch [3/5], Step [40/47], Loss: 1.5253, batch time: 0.06, accuracy:  53.91%
# Training round [397/400], Epoch [4/5], Step [20/47], Loss: 1.4843, batch time: 0.06, accuracy:  49.22%
# Training round [397/400], Epoch [4/5], Step [40/47], Loss: 1.3849, batch time: 0.06, accuracy:  58.59%
# Training round [397/400], Epoch [5/5], Step [20/47], Loss: 1.4335, batch time: 0.06, accuracy:  59.38%
# Training round [397/400], Epoch [5/5], Step [40/47], Loss: 1.4234, batch time: 0.06, accuracy:  50.00%
# Training round [397/400], qnn_train_step: [100/500], loss: 11.898850440979004, accuracy: 17.0 %
# Training round [397/400], qnn_train_step: [200/500], loss: 1.4507452249526978, accuracy: 53.6 %
# Training round [397/400], qnn_train_step: [300/500], loss: 1.4267950057983398, accuracy: 54.5 %
# Training round [397/400], qnn_train_step: [400/500], loss: 1.4648778438568115, accuracy: 52.9 %
# Training round [397/400], qnn_train_step: [500/500], loss: 1.4340122938156128, accuracy: 54.2 %
# -----------------------
# Training round [398/400], Epoch [1/5], Step [20/47], Loss: 1.3086, batch time: 0.06, accuracy:  55.47%
# Training round [398/400], Epoch [1/5], Step [40/47], Loss: 1.3920, batch time: 0.06, accuracy:  61.72%
# Training round [398/400], Epoch [2/5], Step [20/47], Loss: 1.2852, batch time: 0.06, accuracy:  57.03%
# Training round [398/400], Epoch [2/5], Step [40/47], Loss: 1.3319, batch time: 0.03, accuracy:  53.12%
# Training round [398/400], Epoch [3/5], Step [20/47], Loss: 1.5182, batch time: 0.06, accuracy:  49.22%
# Training round [398/400], Epoch [3/5], Step [40/47], Loss: 1.2614, batch time: 0.06, accuracy:  62.50%
# Training round [398/400], Epoch [4/5], Step [20/47], Loss: 1.5157, batch time: 0.06, accuracy:  50.00%
# Training round [398/400], Epoch [4/5], Step [40/47], Loss: 1.4014, batch time: 0.06, accuracy:  54.69%
# Training round [398/400], Epoch [5/5], Step [20/47], Loss: 1.4134, batch time: 0.06, accuracy:  51.56%
# Training round [398/400], Epoch [5/5], Step [40/47], Loss: 1.1519, batch time: 0.06, accuracy:  65.62%
# Training round [398/400], qnn_train_step: [100/500], loss: 12.005300521850586, accuracy: 15.5 %
# Training round [398/400], qnn_train_step: [200/500], loss: 1.7674165964126587, accuracy: 43.6 %
# Training round [398/400], qnn_train_step: [300/500], loss: 1.4537098407745361, accuracy: 53.3 %
# Training round [398/400], qnn_train_step: [400/500], loss: 1.4533331394195557, accuracy: 52.8 %
# Training round [398/400], qnn_train_step: [500/500], loss: 1.4530836343765259, accuracy: 53.2 %
# -----------------------
# Training round [399/400], Epoch [1/5], Step [20/47], Loss: 1.3299, batch time: 0.03, accuracy:  57.03%
# Training round [399/400], Epoch [1/5], Step [40/47], Loss: 1.6185, batch time: 0.03, accuracy:  47.66%
# Training round [399/400], Epoch [2/5], Step [20/47], Loss: 1.1860, batch time: 0.06, accuracy:  57.81%
# Training round [399/400], Epoch [2/5], Step [40/47], Loss: 1.3544, batch time: 0.03, accuracy:  55.47%
# Training round [399/400], Epoch [3/5], Step [20/47], Loss: 1.5286, batch time: 0.06, accuracy:  46.88%
# Training round [399/400], Epoch [3/5], Step [40/47], Loss: 1.3766, batch time: 0.06, accuracy:  55.47%
# Training round [399/400], Epoch [4/5], Step [20/47], Loss: 1.4218, batch time: 0.06, accuracy:  53.91%
# Training round [399/400], Epoch [4/5], Step [40/47], Loss: 1.5663, batch time: 0.06, accuracy:  49.22%
# Training round [399/400], Epoch [5/5], Step [20/47], Loss: 1.3705, batch time: 0.06, accuracy:  54.69%
# Training round [399/400], Epoch [5/5], Step [40/47], Loss: 1.5394, batch time: 0.07, accuracy:  51.56%
# Training round [399/400], qnn_train_step: [100/500], loss: 11.716477394104004, accuracy: 16.5 %
# Training round [399/400], qnn_train_step: [200/500], loss: 1.7260088920593262, accuracy: 45.0 %
# Training round [399/400], qnn_train_step: [300/500], loss: 1.4429863691329956, accuracy: 49.6 %
# Training round [399/400], qnn_train_step: [400/500], loss: 1.3782644271850586, accuracy: 54.1 %
# Training round [399/400], qnn_train_step: [500/500], loss: 1.3752760887145996, accuracy: 53.2 %
# -----------------------
# Training round [400/400], Epoch [1/5], Step [20/47], Loss: 1.4674, batch time: 0.06, accuracy:  53.12%
# Training round [400/400], Epoch [1/5], Step [40/47], Loss: 1.3035, batch time: 0.06, accuracy:  56.25%
# Training round [400/400], Epoch [2/5], Step [20/47], Loss: 1.4261, batch time: 0.03, accuracy:  52.34%
# Training round [400/400], Epoch [2/5], Step [40/47], Loss: 1.3083, batch time: 0.03, accuracy:  58.59%
# Training round [400/400], Epoch [3/5], Step [20/47], Loss: 1.5529, batch time: 0.03, accuracy:  53.12%
# Training round [400/400], Epoch [3/5], Step [40/47], Loss: 1.4736, batch time: 0.03, accuracy:  50.00%
# Training round [400/400], Epoch [4/5], Step [20/47], Loss: 1.4893, batch time: 0.03, accuracy:  51.56%
# Training round [400/400], Epoch [4/5], Step [40/47], Loss: 1.4694, batch time: 0.03, accuracy:  53.12%
# Training round [400/400], Epoch [5/5], Step [20/47], Loss: 1.2122, batch time: 0.06, accuracy:  63.28%
# Training round [400/400], Epoch [5/5], Step [40/47], Loss: 1.4515, batch time: 0.06, accuracy:  50.78%
# Training round [400/400], qnn_train_step: [100/500], loss: 10.719672203063965, accuracy: 18.0 %
# Training round [400/400], qnn_train_step: [200/500], loss: 1.6813634634017944, accuracy: 43.5 %
# Training round [400/400], qnn_train_step: [300/500], loss: 1.4743667840957642, accuracy: 48.0 %
# Training round [400/400], qnn_train_step: [400/500], loss: 1.5003621578216553, accuracy: 48.6 %
# Training round [400/400], qnn_train_step: [500/500], loss: 1.4193350076675415, accuracy: 52.5 %

# %%
plt.plot(loss_list)
plt.ylim(0.5, 2.5)
plt.show()

# %%
# Testing train loop
qt_model.eval()
correct = 0
total = 0
loss_train_list = []
with torch.no_grad():
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = qt_model(images, qnn_parameters)
        loss_train = criterion(outputs, labels).cpu().detach().numpy()
        loss_train_list.append(loss_train)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the train set: {(100 * correct / total):.2f}%")
print(f"Loss on the train set: {np.mean(loss_train_list):.2f}")

# Testing loop
qt_model.eval()
correct = 0
total = 0
loss_test_list = []

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = qt_model(images, qnn_parameters)
        loss_test = criterion(outputs, labels).cpu().detach().numpy()
        loss_test_list.append(loss_test)

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the test set: {(100 * correct / total):.2f}%")
print(f"Loss on the test set: {np.mean(loss_test_list):.2f}")

print("Generalization error:", np.mean(loss_test_list) - np.mean(loss_train_list))
# Out:
# Accuracy on the train set: 53.77%
# Loss on the train set: 1.42
# Accuracy on the test set: 47.83%
# Loss on the test set: 1.48
# Generalization error: 0.063791275

# %%
# # Testing train loop
# model.eval()
# correct = 0
# total = 0
# loss_train_list = []
# with torch.no_grad():
#     for images, labels in train_loader:
#         images, labels = images.to(device), labels.to(device)  # Move data to GPU
#         outputs = model(images)
#         loss_train = criterion(outputs, labels).cpu().detach().numpy()
#         loss_train_list.append(loss_train)
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

# print(f"Accuracy on the train set: {(100 * correct / total):.2f}%")
# print(f"Loss on the train set: {np.mean(loss_train_list):.2f}")

# # Testing loop
# model.eval()
# correct = 0
# total = 0
# loss_test_list = []

# with torch.no_grad():
#     for images, labels in val_loader:
#         images, labels = images.to(device), labels.to(device)  # Move data to GPU
#         outputs = model(images)
#         loss_test = criterion(outputs, labels).cpu().detach().numpy()
#         loss_test_list.append(loss_test)

#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

# print(f"Accuracy on the test set: {(100 * correct / total):.2f}%")
# print(f"Loss on the test set: {np.mean(loss_test_list):.2f}")

# print("Generalization error:", np.mean(loss_test_list) - np.mean(loss_train_list))

# %%
# def fit(
#     epochs: int,
#     lr: float,
#     model: torch.nn.Module,
#     train_loader: DataLoader,
#     val_loader: DataLoader,
#     bs: BosonSampler,
#     opt_func=torch.optim.SGD,
#     save_csv: bool = True,
#     csv_path: str = "training_history"
# ):
#     """
#     Trains the model for a specified number of epochs, evaluates on validation data,
#     and optionally saves the training history to a CSV file with a timestamp.

#     Args:
#         epochs (int): Number of epochs to train.
#         lr (float): Learning rate.
#         model (torch.nn.Module): The neural network model to train.
#         train_loader (DataLoader): DataLoader for training data.
#         val_loader (DataLoader): DataLoader for validation data.
#         bs (BosonSampler): BosonSampler instance for embedding.
#         opt_func (torch.optim.Optimizer, optional): Optimizer constructor. Defaults to torch.optim.SGD.
#         save_csv (bool, optional): Whether to save the training history to a CSV file. Defaults to True.
#         csv_path (str, optional): Base path/name for the CSV file. A timestamp will be appended. Defaults to "training_history".

#     Returns:
#         dict: A dictionary containing training and validation metrics per epoch.
#     """
#     # Initialize optimizer
#     optimizer = opt_func(model.parameters(), lr=lr)
#     criterion = torch.nn.CrossEntropyLoss()

#     # Initialize history dictionary
#     history = {
#         'epoch': [],
#         'train_loss': [],
#         'train_acc': [],
#         'val_loss': [],
#         'val_acc': []
#     }

#     # Determine the device from the model
#     device = next(model.parameters()).device
#     print(f"Training on device: {device}")

#     # Create a progress bar for epochs
#     epoch_bar = tqdm(range(1, epochs + 1), desc="Training Progress", unit="epoch")

#     for epoch in epoch_bar:
#         model.train()
#         running_loss = 0.0
#         running_corrects = 0
#         total_samples = 0

#         # Iterate over training data
#         for batch in train_loader:
#             if model.embedding_size:
#                 images, labels = batch
#                 # Move images and labels to the device
#                 images = images.to(device)
#                 labels = labels.to(device)

#                 # Generate embeddings and move them to the device
#                 embs = bs.embed(images, n_sample=1000).to(device)

#                 # Forward pass with embeddings
#                 outputs = model(images, emb=embs.unsqueeze(0))
#             else:
#                 images, labels = batch
#                 # Move images and labels to the device
#                 images = images.to(device)
#                 labels = labels.to(device)

#                 # Forward pass without embeddings
#                 outputs = model(images)

#             # Compute loss
#             loss = criterion(outputs, labels)

#             # Compute accuracy
#             _, preds = torch.max(outputs, 1)
#             acc = torch.sum(preds == labels.data).item()

#             # Backward pass and optimization
#             optimizer.zero_grad()
#             loss.backward()
#             optimizer.step()

#             # Accumulate loss and accuracy
#             running_loss += loss.item() * images.size(0)
#             running_corrects += acc
#             total_samples += images.size(0)

#         # Calculate epoch metrics
#         epoch_train_loss = running_loss / total_samples
#         epoch_train_acc = running_corrects / total_samples

#         # Validation phase
#         model.eval()
#         val_running_loss = 0.0
#         val_running_corrects = 0
#         val_total_samples = 0

#         with torch.no_grad():
#             for batch in val_loader:
#                 if model.embedding_size:
#                     images, labels = batch
#                     # Move images and labels to the device
#                     images = images.to(device)
#                     labels = labels.to(device)

#                     # Generate embeddings and move them to the device
#                     embs = bs.embed(images, n_sample=1000).to(device)

#                     # Forward pass with embeddings
#                     outputs = model(images, emb=embs.unsqueeze(0))
#                 else:
#                     images, labels = batch
#                     # Move images and labels to the device
#                     images = images.to(device)
#                     labels = labels.to(device)

#                     # Forward pass without embeddings
#                     outputs = model(images)

#                 # Compute loss
#                 loss = criterion(outputs, labels)

#                 # Compute accuracy
#                 _, preds = torch.max(outputs, 1)
#                 acc = torch.sum(preds == labels.data).item()

#                 # Accumulate loss and accuracy
#                 val_running_loss += loss.item() * images.size(0)
#                 val_running_corrects += acc
#                 val_total_samples += images.size(0)

#         # Calculate validation metrics
#         epoch_val_loss = val_running_loss / val_total_samples
#         epoch_val_acc = val_running_corrects / val_total_samples

#         # Update history
#         history['epoch'].append(epoch)
#         history['train_loss'].append(epoch_train_loss)
#         history['train_acc'].append(epoch_train_acc)
#         history['val_loss'].append(epoch_val_loss)
#         history['val_acc'].append(epoch_val_acc)

#         # Update the progress bar description
#         epoch_bar.set_postfix({
#             'Train Loss': f"{epoch_train_loss:.4f}",
#             'Train Acc': f"{epoch_train_acc:.4f}",
#             'Val Loss': f"{epoch_val_loss:.4f}",
#             'Val Acc': f"{epoch_val_acc:.4f}"
#         })

#     # Save history to CSV with timestamp
#     if save_csv:
#         timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
#         csv_filename = f"{csv_path}_{timestamp}.csv"
#         history_df = pd.DataFrame(history)
#         history_df.to_csv(csv_filename, index=False)
#         print(f"\nTraining history saved to '{csv_filename}'.")

#     return history
