# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from sklearn.mixture import GaussianMixture
from torch.utils.data import DataLoader
from utils import MNIST_partial, accuracy, plot_training_metrics

# %%
# Hyperparameters
batch_size = 64
learning_rate = 1e-4
num_epochs = 50
shared_rows = 10  # Number of clusters for GMM

# dataset from csv file, to use for the challenge
train_dataset = MNIST_partial(split="train")
val_dataset = MNIST_partial(split="val")

# definition of the dataloader, to process the data in the model
# here, we need a batch size of 1 to use the boson sampler
batch_size = 128
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size, shuffle=False)


class SharedWeightFC(nn.Module):
    def __init__(self, in_features, out_features, shared_rows):
        """
        A fully connected layer with static weight sharing.

        Parameters:
        - in_features: Size of the input.
        - out_features: Size of the output.
        - shared_rows: Number of unique rows to use for sharing weights.
        """
        super(SharedWeightFC, self).__init__()

        # Initialize a small set of trainable rows
        self.shared_weights = nn.Parameter(torch.randn(shared_rows, in_features))

        # Bias term for the fully connected layer
        self.bias = nn.Parameter(torch.randn(out_features))

        # Store how many rows are shared
        self.out_features = out_features
        self.shared_rows = shared_rows

    def forward(self, x):
        # Repeat the shared rows to build the full weight matrix
        weight_matrix = self.shared_weights.repeat(
            self.out_features // self.shared_rows, 1
        )

        # Matrix multiplication followed by bias addition
        return torch.matmul(x, weight_matrix.t()) + self.bias


# Define a CNN model with FC layers generated by GMM
class CNNModel(nn.Module):
    def __init__(self, shared_rows):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=5)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(8, 12, kernel_size=5)

        # Replace standard FC layers with GMM-generated FC layers
        self.fc1 = SharedWeightFC(
            in_features=12 * 4 * 4, out_features=20, shared_rows=shared_rows
        )
        self.fc2 = nn.Linear(
            20, 10
        )  # SharedWeightFC(in_features=20, out_features=10, shared_rows=shared_rows) #nn.Linear(20, 10)

    def forward(self, x):
        x = self.pool(self.conv1(x))
        x = self.pool(self.conv2(x))
        x = x.view(x.size(0), -1)  # [N, 32 * 8 * 8]
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %%
# Instantiate the model
model = CNNModel(shared_rows=shared_rows)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)


# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)


# Training loop
def train(model, train_loader, optimizer, criterion):
    model.train()
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)  # Move data to GPU

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            if (i + 1) % 10 == 0:
                print(
                    f"Epoch [{epoch + 1}/{num_epochs}], Step [{(i + 1)}/{len(train_loader)}], Loss: {loss.item():.4f}"
                )


sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 4770

# %%
# Train the model
train(model, train_loader, optimizer, criterion)
# Out:
# Epoch [1/50], Step [10/47], Loss: 3.1089
# Epoch [1/50], Step [20/47], Loss: 2.8428
# Epoch [1/50], Step [30/47], Loss: 2.5481
# Epoch [1/50], Step [40/47], Loss: 2.4872
# Epoch [2/50], Step [10/47], Loss: 2.4965
# Epoch [2/50], Step [20/47], Loss: 2.4975
# Epoch [2/50], Step [30/47], Loss: 2.3268
# Epoch [2/50], Step [40/47], Loss: 2.3264
# Epoch [3/50], Step [10/47], Loss: 2.1255
# Epoch [3/50], Step [20/47], Loss: 2.1246
# Epoch [3/50], Step [30/47], Loss: 2.0580
# Epoch [3/50], Step [40/47], Loss: 1.9900
# Epoch [4/50], Step [10/47], Loss: 2.0556
# Epoch [4/50], Step [20/47], Loss: 1.8985
# Epoch [4/50], Step [30/47], Loss: 1.8953
# Epoch [4/50], Step [40/47], Loss: 1.8339
# Epoch [5/50], Step [10/47], Loss: 1.5766
# Epoch [5/50], Step [20/47], Loss: 1.7068
# Epoch [5/50], Step [30/47], Loss: 1.6474
# Epoch [5/50], Step [40/47], Loss: 1.7643
# Epoch [6/50], Step [10/47], Loss: 1.5845
# Epoch [6/50], Step [20/47], Loss: 1.5667
# Epoch [6/50], Step [30/47], Loss: 1.5361
# Epoch [6/50], Step [40/47], Loss: 1.5619
# Epoch [7/50], Step [10/47], Loss: 1.5519
# Epoch [7/50], Step [20/47], Loss: 1.2728
# Epoch [7/50], Step [30/47], Loss: 1.3722
# Epoch [7/50], Step [40/47], Loss: 1.3814
# Epoch [8/50], Step [10/47], Loss: 1.1581
# Epoch [8/50], Step [20/47], Loss: 1.3187
# Epoch [8/50], Step [30/47], Loss: 1.3070
# Epoch [8/50], Step [40/47], Loss: 1.2422
# Epoch [9/50], Step [10/47], Loss: 1.2035
# Epoch [9/50], Step [20/47], Loss: 1.1117
# Epoch [9/50], Step [30/47], Loss: 1.1227
# Epoch [9/50], Step [40/47], Loss: 1.0564
# Epoch [10/50], Step [10/47], Loss: 1.1528
# Epoch [10/50], Step [20/47], Loss: 1.1560
# Epoch [10/50], Step [30/47], Loss: 1.0773
# Epoch [10/50], Step [40/47], Loss: 1.0451
# Epoch [11/50], Step [10/47], Loss: 0.8771
# Epoch [11/50], Step [20/47], Loss: 1.0240
# Epoch [11/50], Step [30/47], Loss: 0.9477
# Epoch [11/50], Step [40/47], Loss: 0.8740
# Epoch [12/50], Step [10/47], Loss: 0.9868
# Epoch [12/50], Step [20/47], Loss: 0.9058
# Epoch [12/50], Step [30/47], Loss: 0.8559
# Epoch [12/50], Step [40/47], Loss: 0.9296
# Epoch [13/50], Step [10/47], Loss: 0.8285
# Epoch [13/50], Step [20/47], Loss: 0.8252
# Epoch [13/50], Step [30/47], Loss: 0.8049
# Epoch [13/50], Step [40/47], Loss: 0.8170
# Epoch [14/50], Step [10/47], Loss: 0.8547
# Epoch [14/50], Step [20/47], Loss: 0.8791
# Epoch [14/50], Step [30/47], Loss: 0.7457
# Epoch [14/50], Step [40/47], Loss: 0.8421
# Epoch [15/50], Step [10/47], Loss: 0.6806
# Epoch [15/50], Step [20/47], Loss: 0.7782
# Epoch [15/50], Step [30/47], Loss: 0.6680
# Epoch [15/50], Step [40/47], Loss: 0.6549
# Epoch [16/50], Step [10/47], Loss: 0.8444
# Epoch [16/50], Step [20/47], Loss: 0.6350
# Epoch [16/50], Step [30/47], Loss: 0.7918
# Epoch [16/50], Step [40/47], Loss: 0.5327
# Epoch [17/50], Step [10/47], Loss: 0.6165
# Epoch [17/50], Step [20/47], Loss: 0.8047
# Epoch [17/50], Step [30/47], Loss: 0.6604
# Epoch [17/50], Step [40/47], Loss: 0.7093
# Epoch [18/50], Step [10/47], Loss: 0.6576
# Epoch [18/50], Step [20/47], Loss: 0.6811
# Epoch [18/50], Step [30/47], Loss: 0.6960
# Epoch [18/50], Step [40/47], Loss: 0.5937
# Epoch [19/50], Step [10/47], Loss: 0.8404
# Epoch [19/50], Step [20/47], Loss: 0.7045
# Epoch [19/50], Step [30/47], Loss: 0.6413
# Epoch [19/50], Step [40/47], Loss: 0.5568
# Epoch [20/50], Step [10/47], Loss: 0.5711
# Epoch [20/50], Step [20/47], Loss: 0.5779
# Epoch [20/50], Step [30/47], Loss: 0.5074
# Epoch [20/50], Step [40/47], Loss: 0.6012
# Epoch [21/50], Step [10/47], Loss: 0.4484
# Epoch [21/50], Step [20/47], Loss: 0.6188
# Epoch [21/50], Step [30/47], Loss: 0.5681
# Epoch [21/50], Step [40/47], Loss: 0.4812
# Epoch [22/50], Step [10/47], Loss: 0.4446
# Epoch [22/50], Step [20/47], Loss: 0.4363
# Epoch [22/50], Step [30/47], Loss: 0.5661
# Epoch [22/50], Step [40/47], Loss: 0.6014
# Epoch [23/50], Step [10/47], Loss: 0.5151
# Epoch [23/50], Step [20/47], Loss: 0.4867
# Epoch [23/50], Step [30/47], Loss: 0.5345
# Epoch [23/50], Step [40/47], Loss: 0.4955
# Epoch [24/50], Step [10/47], Loss: 0.4469
# Epoch [24/50], Step [20/47], Loss: 0.3846
# Epoch [24/50], Step [30/47], Loss: 0.5956
# Epoch [24/50], Step [40/47], Loss: 0.4653
# Epoch [25/50], Step [10/47], Loss: 0.4250
# Epoch [25/50], Step [20/47], Loss: 0.4345
# Epoch [25/50], Step [30/47], Loss: 0.3395
# Epoch [25/50], Step [40/47], Loss: 0.6750
# Epoch [26/50], Step [10/47], Loss: 0.3367
# Epoch [26/50], Step [20/47], Loss: 0.2774
# Epoch [26/50], Step [30/47], Loss: 0.3909
# Epoch [26/50], Step [40/47], Loss: 0.4512
# Epoch [27/50], Step [10/47], Loss: 0.4528
# Epoch [27/50], Step [20/47], Loss: 0.4194
# Epoch [27/50], Step [30/47], Loss: 0.4073
# Epoch [27/50], Step [40/47], Loss: 0.4575
# Epoch [28/50], Step [10/47], Loss: 0.3995
# Epoch [28/50], Step [20/47], Loss: 0.4882
# Epoch [28/50], Step [30/47], Loss: 0.3319
# Epoch [28/50], Step [40/47], Loss: 0.4691
# Epoch [29/50], Step [10/47], Loss: 0.4395
# Epoch [29/50], Step [20/47], Loss: 0.4340
# Epoch [29/50], Step [30/47], Loss: 0.3442
# Epoch [29/50], Step [40/47], Loss: 0.4287
# Epoch [30/50], Step [10/47], Loss: 0.4363
# Epoch [30/50], Step [20/47], Loss: 0.4557
# Epoch [30/50], Step [30/47], Loss: 0.4567
# Epoch [30/50], Step [40/47], Loss: 0.4732
# Epoch [31/50], Step [10/47], Loss: 0.3263
# Epoch [31/50], Step [20/47], Loss: 0.3296
# Epoch [31/50], Step [30/47], Loss: 0.3717
# Epoch [31/50], Step [40/47], Loss: 0.4773
# Epoch [32/50], Step [10/47], Loss: 0.4480
# Epoch [32/50], Step [20/47], Loss: 0.4998
# Epoch [32/50], Step [30/47], Loss: 0.3601
# Epoch [32/50], Step [40/47], Loss: 0.3655
# Epoch [33/50], Step [10/47], Loss: 0.4283
# Epoch [33/50], Step [20/47], Loss: 0.2650
# Epoch [33/50], Step [30/47], Loss: 0.4295
# Epoch [33/50], Step [40/47], Loss: 0.2667
# Epoch [34/50], Step [10/47], Loss: 0.3000
# Epoch [34/50], Step [20/47], Loss: 0.4264
# Epoch [34/50], Step [30/47], Loss: 0.3879
# Epoch [34/50], Step [40/47], Loss: 0.4327
# Epoch [35/50], Step [10/47], Loss: 0.3210
# Epoch [35/50], Step [20/47], Loss: 0.3309
# Epoch [35/50], Step [30/47], Loss: 0.5417
# Epoch [35/50], Step [40/47], Loss: 0.2924
# Epoch [36/50], Step [10/47], Loss: 0.3205
# Epoch [36/50], Step [20/47], Loss: 0.2934
# Epoch [36/50], Step [30/47], Loss: 0.3566
# Epoch [36/50], Step [40/47], Loss: 0.4202
# Epoch [37/50], Step [10/47], Loss: 0.3466
# Epoch [37/50], Step [20/47], Loss: 0.3400
# Epoch [37/50], Step [30/47], Loss: 0.3014
# Epoch [37/50], Step [40/47], Loss: 0.3810
# Epoch [38/50], Step [10/47], Loss: 0.3030
# Epoch [38/50], Step [20/47], Loss: 0.3322
# Epoch [38/50], Step [30/47], Loss: 0.4036
# Epoch [38/50], Step [40/47], Loss: 0.2926
# Epoch [39/50], Step [10/47], Loss: 0.3258
# Epoch [39/50], Step [20/47], Loss: 0.3696
# Epoch [39/50], Step [30/47], Loss: 0.3360
# Epoch [39/50], Step [40/47], Loss: 0.3855
# Epoch [40/50], Step [10/47], Loss: 0.3814
# Epoch [40/50], Step [20/47], Loss: 0.5046
# Epoch [40/50], Step [30/47], Loss: 0.3162
# Epoch [40/50], Step [40/47], Loss: 0.2833
# Epoch [41/50], Step [10/47], Loss: 0.4392
# Epoch [41/50], Step [20/47], Loss: 0.3816
# Epoch [41/50], Step [30/47], Loss: 0.3292
# Epoch [41/50], Step [40/47], Loss: 0.3203
# Epoch [42/50], Step [10/47], Loss: 0.3663
# Epoch [42/50], Step [20/47], Loss: 0.3047
# Epoch [42/50], Step [30/47], Loss: 0.2769
# Epoch [42/50], Step [40/47], Loss: 0.2523
# Epoch [43/50], Step [10/47], Loss: 0.2765
# Epoch [43/50], Step [20/47], Loss: 0.4031
# Epoch [43/50], Step [30/47], Loss: 0.3099
# Epoch [43/50], Step [40/47], Loss: 0.3520
# Epoch [44/50], Step [10/47], Loss: 0.2912
# Epoch [44/50], Step [20/47], Loss: 0.1541
# Epoch [44/50], Step [30/47], Loss: 0.4897
# Epoch [44/50], Step [40/47], Loss: 0.3737
# Epoch [45/50], Step [10/47], Loss: 0.3423
# Epoch [45/50], Step [20/47], Loss: 0.3037
# Epoch [45/50], Step [30/47], Loss: 0.4002
# Epoch [45/50], Step [40/47], Loss: 0.3422
# Epoch [46/50], Step [10/47], Loss: 0.2120
# Epoch [46/50], Step [20/47], Loss: 0.3374
# Epoch [46/50], Step [30/47], Loss: 0.2029
# Epoch [46/50], Step [40/47], Loss: 0.3130
# Epoch [47/50], Step [10/47], Loss: 0.3497
# Epoch [47/50], Step [20/47], Loss: 0.3241
# Epoch [47/50], Step [30/47], Loss: 0.2854
# Epoch [47/50], Step [40/47], Loss: 0.3676
# Epoch [48/50], Step [10/47], Loss: 0.2365
# Epoch [48/50], Step [20/47], Loss: 0.3045
# Epoch [48/50], Step [30/47], Loss: 0.3696
# Epoch [48/50], Step [40/47], Loss: 0.2841
# Epoch [49/50], Step [10/47], Loss: 0.2182
# Epoch [49/50], Step [20/47], Loss: 0.4226
# Epoch [49/50], Step [30/47], Loss: 0.3705
# Epoch [49/50], Step [40/47], Loss: 0.3264
# Epoch [50/50], Step [10/47], Loss: 0.3530
# Epoch [50/50], Step [20/47], Loss: 0.2209
# Epoch [50/50], Step [30/47], Loss: 0.4198
# Epoch [50/50], Step [40/47], Loss: 0.1983

# %%
# Test the model
def test(model, test_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)  # Move data to GPU

            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print(f"Test Accuracy: {100 * correct / total:.2f}%")


# Test the model after training
test(model, val_loader)
# Out:
# Test Accuracy: 90.33%

# %%
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 4770

# %%
# for i in model.fc1.parameters():
#     print(i)

# %%
# 1, 2, 4, 5, 10
# weight_sharing_parameter_num_list = [3042, 3234, 3618, 3810, 4770]

# weight_sharing_test_acc_list = [
#                                 [56.25, 89.43, 95.58, 96.95, 97.61],
#                                 [57.55, 86.67, 95.21, 96.27, 97.86],
#                                 [59.63, 88.32, 95.71, 96.51, 97.92]
#                                 ]

weight_sharing_parameter_num_list = [3042, 3234, 3618, 3810, 4770]

weight_sharing_test_acc_list = [
    [
        37.00,
    ],
    [
        38.33,
    ],
    [
        38.83,
    ],
]
