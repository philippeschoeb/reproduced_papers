# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from sklearn.mixture import GaussianMixture
from torch.utils.data import DataLoader
from utils import MNIST_partial, accuracy, plot_training_metrics

# %%
# Hyperparameters
batch_size = 64
learning_rate = 1e-4
num_epochs = 50
shared_rows = 10  # Number of clusters for GMM

# dataset from csv file, to use for the challenge
train_dataset = MNIST_partial(split="train")
val_dataset = MNIST_partial(split="val")

# definition of the dataloader, to process the data in the model
# here, we need a batch size of 1 to use the boson sampler
batch_size = 128
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size, shuffle=False)


class SharedWeightFC(nn.Module):
    def __init__(self, in_features, out_features, shared_rows):
        """
        A fully connected layer with static weight sharing.

        Parameters:
        - in_features: Size of the input.
        - out_features: Size of the output.
        - shared_rows: Number of unique rows to use for sharing weights.
        """
        super(SharedWeightFC, self).__init__()

        # Initialize a small set of trainable rows
        self.shared_weights = nn.Parameter(torch.randn(shared_rows, in_features))

        # Bias term for the fully connected layer
        self.bias = nn.Parameter(torch.randn(out_features))

        # Store how many rows are shared
        self.out_features = out_features
        self.shared_rows = shared_rows

    def forward(self, x):
        # Repeat the shared rows to build the full weight matrix
        weight_matrix = self.shared_weights.repeat(
            self.out_features // self.shared_rows, 1
        )

        # Matrix multiplication followed by bias addition
        return torch.matmul(x, weight_matrix.t()) + self.bias


# Define a CNN model with FC layers generated by GMM
class CNNModel(nn.Module):
    def __init__(self, shared_rows):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=5)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(8, 12, kernel_size=5)

        # Replace standard FC layers with GMM-generated FC layers
        self.fc1 = SharedWeightFC(
            in_features=12 * 4 * 4, out_features=20, shared_rows=shared_rows
        )
        self.fc2 = nn.Linear(
            20, 10
        )  # SharedWeightFC(in_features=20, out_features=10, shared_rows=shared_rows) #nn.Linear(20, 10)

    def forward(self, x):
        x = self.pool(self.conv1(x))
        x = self.pool(self.conv2(x))
        x = x.view(x.size(0), -1)  # [N, 32 * 8 * 8]
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %%
# Instantiate the model
model = CNNModel(shared_rows=shared_rows)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)


# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)


# Training loop
def train(model, train_loader, optimizer, criterion):
    model.train()
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)  # Move data to GPU

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            if (i + 1) % 10 == 0:
                print(
                    f"Epoch [{epoch + 1}/{num_epochs}], Step [{(i + 1)}/{len(train_loader)}], Loss: {loss.item():.4f}"
                )


sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 4770

# %%
# Train the model
train(model, train_loader, optimizer, criterion)
# Out:
# Epoch [1/50], Step [10/47], Loss: 2.5353
# Epoch [1/50], Step [20/47], Loss: 2.3939
# Epoch [1/50], Step [30/47], Loss: 2.2878
# Epoch [1/50], Step [40/47], Loss: 2.2532
# Epoch [2/50], Step [10/47], Loss: 2.1066
# Epoch [2/50], Step [20/47], Loss: 2.0774
# Epoch [2/50], Step [30/47], Loss: 1.8601
# Epoch [2/50], Step [40/47], Loss: 1.8872
# Epoch [3/50], Step [10/47], Loss: 1.8697
# Epoch [3/50], Step [20/47], Loss: 1.6870
# Epoch [3/50], Step [30/47], Loss: 1.6992
# Epoch [3/50], Step [40/47], Loss: 1.6135
# Epoch [4/50], Step [10/47], Loss: 1.5781
# Epoch [4/50], Step [20/47], Loss: 1.5577
# Epoch [4/50], Step [30/47], Loss: 1.5247
# Epoch [4/50], Step [40/47], Loss: 1.4367
# Epoch [5/50], Step [10/47], Loss: 1.3255
# Epoch [5/50], Step [20/47], Loss: 1.4472
# Epoch [5/50], Step [30/47], Loss: 1.4605
# Epoch [5/50], Step [40/47], Loss: 1.2201
# Epoch [6/50], Step [10/47], Loss: 1.1797
# Epoch [6/50], Step [20/47], Loss: 1.1146
# Epoch [6/50], Step [30/47], Loss: 1.1836
# Epoch [6/50], Step [40/47], Loss: 1.0430
# Epoch [7/50], Step [10/47], Loss: 1.0629
# Epoch [7/50], Step [20/47], Loss: 1.0627
# Epoch [7/50], Step [30/47], Loss: 1.0713
# Epoch [7/50], Step [40/47], Loss: 1.0314
# Epoch [8/50], Step [10/47], Loss: 1.0138
# Epoch [8/50], Step [20/47], Loss: 0.9819
# Epoch [8/50], Step [30/47], Loss: 1.0058
# Epoch [8/50], Step [40/47], Loss: 0.8171
# Epoch [9/50], Step [10/47], Loss: 0.9090
# Epoch [9/50], Step [20/47], Loss: 0.9898
# Epoch [9/50], Step [30/47], Loss: 0.9042
# Epoch [9/50], Step [40/47], Loss: 0.8285
# Epoch [10/50], Step [10/47], Loss: 0.7911
# Epoch [10/50], Step [20/47], Loss: 0.9079
# Epoch [10/50], Step [30/47], Loss: 0.6942
# Epoch [10/50], Step [40/47], Loss: 0.7624
# Epoch [11/50], Step [10/47], Loss: 0.8177
# Epoch [11/50], Step [20/47], Loss: 0.9057
# Epoch [11/50], Step [30/47], Loss: 0.6953
# Epoch [11/50], Step [40/47], Loss: 0.8783
# Epoch [12/50], Step [10/47], Loss: 0.7876
# Epoch [12/50], Step [20/47], Loss: 0.6729
# Epoch [12/50], Step [30/47], Loss: 0.8161
# Epoch [12/50], Step [40/47], Loss: 0.8114
# Epoch [13/50], Step [10/47], Loss: 0.7737
# Epoch [13/50], Step [20/47], Loss: 0.7382
# Epoch [13/50], Step [30/47], Loss: 0.7372
# Epoch [13/50], Step [40/47], Loss: 0.5952
# Epoch [14/50], Step [10/47], Loss: 0.5796
# Epoch [14/50], Step [20/47], Loss: 0.6082
# Epoch [14/50], Step [30/47], Loss: 0.5940
# Epoch [14/50], Step [40/47], Loss: 0.7835
# Epoch [15/50], Step [10/47], Loss: 0.5886
# Epoch [15/50], Step [20/47], Loss: 0.5300
# Epoch [15/50], Step [30/47], Loss: 0.6941
# Epoch [15/50], Step [40/47], Loss: 0.5395
# Epoch [16/50], Step [10/47], Loss: 0.5408
# Epoch [16/50], Step [20/47], Loss: 0.5583
# Epoch [16/50], Step [30/47], Loss: 0.5842
# Epoch [16/50], Step [40/47], Loss: 0.6830
# Epoch [17/50], Step [10/47], Loss: 0.4783
# Epoch [17/50], Step [20/47], Loss: 0.6382
# Epoch [17/50], Step [30/47], Loss: 0.5094
# Epoch [17/50], Step [40/47], Loss: 0.5404
# Epoch [18/50], Step [10/47], Loss: 0.6098
# Epoch [18/50], Step [20/47], Loss: 0.6125
# Epoch [18/50], Step [30/47], Loss: 0.5757
# Epoch [18/50], Step [40/47], Loss: 0.6102
# Epoch [19/50], Step [10/47], Loss: 0.5322
# Epoch [19/50], Step [20/47], Loss: 0.4771
# Epoch [19/50], Step [30/47], Loss: 0.6326
# Epoch [19/50], Step [40/47], Loss: 0.5265
# Epoch [20/50], Step [10/47], Loss: 0.4543
# Epoch [20/50], Step [20/47], Loss: 0.5728
# Epoch [20/50], Step [30/47], Loss: 0.7111
# Epoch [20/50], Step [40/47], Loss: 0.4905
# Epoch [21/50], Step [10/47], Loss: 0.4217
# Epoch [21/50], Step [20/47], Loss: 0.5195
# Epoch [21/50], Step [30/47], Loss: 0.4280
# Epoch [21/50], Step [40/47], Loss: 0.3870
# Epoch [22/50], Step [10/47], Loss: 0.4494
# Epoch [22/50], Step [20/47], Loss: 0.5109
# Epoch [22/50], Step [30/47], Loss: 0.5254
# Epoch [22/50], Step [40/47], Loss: 0.5301
# Epoch [23/50], Step [10/47], Loss: 0.4252
# Epoch [23/50], Step [20/47], Loss: 0.5163
# Epoch [23/50], Step [30/47], Loss: 0.3853
# Epoch [23/50], Step [40/47], Loss: 0.4961
# Epoch [24/50], Step [10/47], Loss: 0.5352
# Epoch [24/50], Step [20/47], Loss: 0.4417
# Epoch [24/50], Step [30/47], Loss: 0.5437
# Epoch [24/50], Step [40/47], Loss: 0.4214
# Epoch [25/50], Step [10/47], Loss: 0.3885
# Epoch [25/50], Step [20/47], Loss: 0.5470
# Epoch [25/50], Step [30/47], Loss: 0.5855
# Epoch [25/50], Step [40/47], Loss: 0.4460
# Epoch [26/50], Step [10/47], Loss: 0.4285
# Epoch [26/50], Step [20/47], Loss: 0.6044
# Epoch [26/50], Step [30/47], Loss: 0.3953
# Epoch [26/50], Step [40/47], Loss: 0.4468
# Epoch [27/50], Step [10/47], Loss: 0.4574
# Epoch [27/50], Step [20/47], Loss: 0.5970
# Epoch [27/50], Step [30/47], Loss: 0.4088
# Epoch [27/50], Step [40/47], Loss: 0.4193
# Epoch [28/50], Step [10/47], Loss: 0.4981
# Epoch [28/50], Step [20/47], Loss: 0.4369
# Epoch [28/50], Step [30/47], Loss: 0.4449
# Epoch [28/50], Step [40/47], Loss: 0.3774
# Epoch [29/50], Step [10/47], Loss: 0.4129
# Epoch [29/50], Step [20/47], Loss: 0.4724
# Epoch [29/50], Step [30/47], Loss: 0.4879
# Epoch [29/50], Step [40/47], Loss: 0.3560
# Epoch [30/50], Step [10/47], Loss: 0.4560
# Epoch [30/50], Step [20/47], Loss: 0.4163
# Epoch [30/50], Step [30/47], Loss: 0.4448
# Epoch [30/50], Step [40/47], Loss: 0.4467
# Epoch [31/50], Step [10/47], Loss: 0.3546
# Epoch [31/50], Step [20/47], Loss: 0.4819
# Epoch [31/50], Step [30/47], Loss: 0.4336
# Epoch [31/50], Step [40/47], Loss: 0.3040
# Epoch [32/50], Step [10/47], Loss: 0.4111
# Epoch [32/50], Step [20/47], Loss: 0.4172
# Epoch [32/50], Step [30/47], Loss: 0.5830
# Epoch [32/50], Step [40/47], Loss: 0.3343
# Epoch [33/50], Step [10/47], Loss: 0.3411
# Epoch [33/50], Step [20/47], Loss: 0.4278
# Epoch [33/50], Step [30/47], Loss: 0.3286
# Epoch [33/50], Step [40/47], Loss: 0.4373
# Epoch [34/50], Step [10/47], Loss: 0.3955
# Epoch [34/50], Step [20/47], Loss: 0.3268
# Epoch [34/50], Step [30/47], Loss: 0.5423
# Epoch [34/50], Step [40/47], Loss: 0.4489
# Epoch [35/50], Step [10/47], Loss: 0.4031
# Epoch [35/50], Step [20/47], Loss: 0.4243
# Epoch [35/50], Step [30/47], Loss: 0.3393
# Epoch [35/50], Step [40/47], Loss: 0.3690
# Epoch [36/50], Step [10/47], Loss: 0.5044
# Epoch [36/50], Step [20/47], Loss: 0.2693
# Epoch [36/50], Step [30/47], Loss: 0.3527
# Epoch [36/50], Step [40/47], Loss: 0.3316
# Epoch [37/50], Step [10/47], Loss: 0.3123
# Epoch [37/50], Step [20/47], Loss: 0.2999
# Epoch [37/50], Step [30/47], Loss: 0.4697
# Epoch [37/50], Step [40/47], Loss: 0.2850
# Epoch [38/50], Step [10/47], Loss: 0.2865
# Epoch [38/50], Step [20/47], Loss: 0.2704
# Epoch [38/50], Step [30/47], Loss: 0.3507
# Epoch [38/50], Step [40/47], Loss: 0.4085
# Epoch [39/50], Step [10/47], Loss: 0.3396
# Epoch [39/50], Step [20/47], Loss: 0.2959
# Epoch [39/50], Step [30/47], Loss: 0.4095
# Epoch [39/50], Step [40/47], Loss: 0.2672
# Epoch [40/50], Step [10/47], Loss: 0.2790
# Epoch [40/50], Step [20/47], Loss: 0.3149
# Epoch [40/50], Step [30/47], Loss: 0.4027
# Epoch [40/50], Step [40/47], Loss: 0.3724
# Epoch [41/50], Step [10/47], Loss: 0.3715
# Epoch [41/50], Step [20/47], Loss: 0.3322
# Epoch [41/50], Step [30/47], Loss: 0.4283
# Epoch [41/50], Step [40/47], Loss: 0.4142
# Epoch [42/50], Step [10/47], Loss: 0.5220
# Epoch [42/50], Step [20/47], Loss: 0.2499
# Epoch [42/50], Step [30/47], Loss: 0.2970
# Epoch [42/50], Step [40/47], Loss: 0.3844
# Epoch [43/50], Step [10/47], Loss: 0.3509
# Epoch [43/50], Step [20/47], Loss: 0.3595
# Epoch [43/50], Step [30/47], Loss: 0.2943
# Epoch [43/50], Step [40/47], Loss: 0.3607
# Epoch [44/50], Step [10/47], Loss: 0.5119
# Epoch [44/50], Step [20/47], Loss: 0.4406
# Epoch [44/50], Step [30/47], Loss: 0.3981
# Epoch [44/50], Step [40/47], Loss: 0.2638
# Epoch [45/50], Step [10/47], Loss: 0.2447
# Epoch [45/50], Step [20/47], Loss: 0.2420
# Epoch [45/50], Step [30/47], Loss: 0.3061
# Epoch [45/50], Step [40/47], Loss: 0.3563
# Epoch [46/50], Step [10/47], Loss: 0.3082
# Epoch [46/50], Step [20/47], Loss: 0.2879
# Epoch [46/50], Step [30/47], Loss: 0.2539
# Epoch [46/50], Step [40/47], Loss: 0.2939
# Epoch [47/50], Step [10/47], Loss: 0.2469
# Epoch [47/50], Step [20/47], Loss: 0.3420
# Epoch [47/50], Step [30/47], Loss: 0.3780
# Epoch [47/50], Step [40/47], Loss: 0.2983
# Epoch [48/50], Step [10/47], Loss: 0.2875
# Epoch [48/50], Step [20/47], Loss: 0.3389
# Epoch [48/50], Step [30/47], Loss: 0.2021
# Epoch [48/50], Step [40/47], Loss: 0.3397
# Epoch [49/50], Step [10/47], Loss: 0.3734
# Epoch [49/50], Step [20/47], Loss: 0.3006
# Epoch [49/50], Step [30/47], Loss: 0.2087
# Epoch [49/50], Step [40/47], Loss: 0.3040
# Epoch [50/50], Step [10/47], Loss: 0.2373
# Epoch [50/50], Step [20/47], Loss: 0.3695
# Epoch [50/50], Step [30/47], Loss: 0.3072
# Epoch [50/50], Step [40/47], Loss: 0.4363

# %%
# Test the model
def test(model, test_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)  # Move data to GPU

            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print(f"Test Accuracy: {100 * correct / total:.2f}%")


# Test the model after training
test(model, val_loader)
# Out:
# Test Accuracy: 88.17%

# %%
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 4770

# %%
# for i in model.fc1.parameters():
#     print(i)

# %%
# 1, 2, 4, 5, 10
# weight_sharing_parameter_num_list = [3042, 3234, 3618, 3810, 4770]

# weight_sharing_test_acc_list = [
#                                 [56.25, 89.43, 95.58, 96.95, 97.61],
#                                 [57.55, 86.67, 95.21, 96.27, 97.86],
#                                 [59.63, 88.32, 95.71, 96.51, 97.92]
#                                 ]

weight_sharing_parameter_num_list = [3042, 3234, 3618, 3810, 4770]

weight_sharing_test_acc_list = [
    [37.00, 69.33, 87.50, 87.67, 88.17],
    [38.33, 67.83, 86.67, 87.67, 87.50],
    [38.83, 65.67, 84.67, 89.83, 90.33],
]
