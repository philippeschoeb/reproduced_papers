# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from sklearn.mixture import GaussianMixture
from torch.utils.data import DataLoader
from utils import MNIST_partial, accuracy, plot_training_metrics

# %%
# Hyperparameters
batch_size = 64
learning_rate = 1e-4
num_epochs = 50
shared_rows = 10  # Number of clusters for GMM

# dataset from csv file, to use for the challenge
train_dataset = MNIST_partial(split="train")
val_dataset = MNIST_partial(split="val")

# definition of the dataloader, to process the data in the model
# here, we need a batch size of 1 to use the boson sampler
batch_size = 128
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size, shuffle=False)


class SharedWeightFC(nn.Module):
    def __init__(self, in_features, out_features, shared_rows):
        """
        A fully connected layer with static weight sharing.

        Parameters:
        - in_features: Size of the input.
        - out_features: Size of the output.
        - shared_rows: Number of unique rows to use for sharing weights.
        """
        super(SharedWeightFC, self).__init__()

        # Initialize a small set of trainable rows
        self.shared_weights = nn.Parameter(torch.randn(shared_rows, in_features))

        # Bias term for the fully connected layer
        self.bias = nn.Parameter(torch.randn(out_features))

        # Store how many rows are shared
        self.out_features = out_features
        self.shared_rows = shared_rows

    def forward(self, x):
        # Repeat the shared rows to build the full weight matrix
        weight_matrix = self.shared_weights.repeat(
            self.out_features // self.shared_rows, 1
        )

        # Matrix multiplication followed by bias addition
        return torch.matmul(x, weight_matrix.t()) + self.bias


# Define a CNN model with FC layers generated by GMM
class CNNModel(nn.Module):
    def __init__(self, shared_rows):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=5)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(8, 12, kernel_size=5)

        # Replace standard FC layers with GMM-generated FC layers
        self.fc1 = SharedWeightFC(
            in_features=12 * 4 * 4, out_features=20, shared_rows=shared_rows
        )
        self.fc2 = nn.Linear(
            20, 10
        )  # SharedWeightFC(in_features=20, out_features=10, shared_rows=shared_rows) #nn.Linear(20, 10)

    def forward(self, x):
        x = self.pool(self.conv1(x))
        x = self.pool(self.conv2(x))
        x = x.view(x.size(0), -1)  # [N, 32 * 8 * 8]
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %%
# Instantiate the model
model = CNNModel(shared_rows=shared_rows)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)


# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)


# Training loop
def train(model, train_loader, optimizer, criterion):
    model.train()
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)  # Move data to GPU

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            if (i + 1) % 10 == 0:
                print(
                    f"Epoch [{epoch + 1}/{num_epochs}], Step [{(i + 1)}/{len(train_loader)}], Loss: {loss.item():.4f}"
                )


sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 4770

# %%
# Train the model
train(model, train_loader, optimizer, criterion)
# Out:
# Epoch [1/50], Step [10/47], Loss: 3.1279
# Epoch [1/50], Step [20/47], Loss: 3.0971
# Epoch [1/50], Step [30/47], Loss: 2.8298
# Epoch [1/50], Step [40/47], Loss: 2.5589
# Epoch [2/50], Step [10/47], Loss: 2.3800
# Epoch [2/50], Step [20/47], Loss: 2.2865
# Epoch [2/50], Step [30/47], Loss: 2.2042
# Epoch [2/50], Step [40/47], Loss: 2.1595
# Epoch [3/50], Step [10/47], Loss: 2.2351
# Epoch [3/50], Step [20/47], Loss: 2.1192
# Epoch [3/50], Step [30/47], Loss: 2.0311
# Epoch [3/50], Step [40/47], Loss: 1.9306
# Epoch [4/50], Step [10/47], Loss: 1.9919
# Epoch [4/50], Step [20/47], Loss: 1.9156
# Epoch [4/50], Step [30/47], Loss: 1.8896
# Epoch [4/50], Step [40/47], Loss: 1.7717
# Epoch [5/50], Step [10/47], Loss: 1.6908
# Epoch [5/50], Step [20/47], Loss: 1.7394
# Epoch [5/50], Step [30/47], Loss: 1.6487
# Epoch [5/50], Step [40/47], Loss: 1.6582
# Epoch [6/50], Step [10/47], Loss: 1.5059
# Epoch [6/50], Step [20/47], Loss: 1.5665
# Epoch [6/50], Step [30/47], Loss: 1.6205
# Epoch [6/50], Step [40/47], Loss: 1.4928
# Epoch [7/50], Step [10/47], Loss: 1.4992
# Epoch [7/50], Step [20/47], Loss: 1.4181
# Epoch [7/50], Step [30/47], Loss: 1.4179
# Epoch [7/50], Step [40/47], Loss: 1.4092
# Epoch [8/50], Step [10/47], Loss: 1.4637
# Epoch [8/50], Step [20/47], Loss: 1.3343
# Epoch [8/50], Step [30/47], Loss: 1.3310
# Epoch [8/50], Step [40/47], Loss: 1.2353
# Epoch [9/50], Step [10/47], Loss: 1.3137
# Epoch [9/50], Step [20/47], Loss: 1.2254
# Epoch [9/50], Step [30/47], Loss: 1.2893
# Epoch [9/50], Step [40/47], Loss: 1.0770
# Epoch [10/50], Step [10/47], Loss: 1.1476
# Epoch [10/50], Step [20/47], Loss: 1.2214
# Epoch [10/50], Step [30/47], Loss: 1.2292
# Epoch [10/50], Step [40/47], Loss: 1.0559
# Epoch [11/50], Step [10/47], Loss: 1.0807
# Epoch [11/50], Step [20/47], Loss: 1.0675
# Epoch [11/50], Step [30/47], Loss: 1.1299
# Epoch [11/50], Step [40/47], Loss: 0.9196
# Epoch [12/50], Step [10/47], Loss: 1.0163
# Epoch [12/50], Step [20/47], Loss: 1.0028
# Epoch [12/50], Step [30/47], Loss: 0.9094
# Epoch [12/50], Step [40/47], Loss: 0.9899
# Epoch [13/50], Step [10/47], Loss: 0.9351
# Epoch [13/50], Step [20/47], Loss: 0.8694
# Epoch [13/50], Step [30/47], Loss: 0.7662
# Epoch [13/50], Step [40/47], Loss: 0.8755
# Epoch [14/50], Step [10/47], Loss: 0.7269
# Epoch [14/50], Step [20/47], Loss: 0.8167
# Epoch [14/50], Step [30/47], Loss: 0.8466
# Epoch [14/50], Step [40/47], Loss: 0.8094
# Epoch [15/50], Step [10/47], Loss: 0.8707
# Epoch [15/50], Step [20/47], Loss: 0.7324
# Epoch [15/50], Step [30/47], Loss: 0.7321
# Epoch [15/50], Step [40/47], Loss: 0.8192
# Epoch [16/50], Step [10/47], Loss: 0.8873
# Epoch [16/50], Step [20/47], Loss: 0.7550
# Epoch [16/50], Step [30/47], Loss: 0.7827
# Epoch [16/50], Step [40/47], Loss: 0.8363
# Epoch [17/50], Step [10/47], Loss: 0.7228
# Epoch [17/50], Step [20/47], Loss: 0.8811
# Epoch [17/50], Step [30/47], Loss: 0.6869
# Epoch [17/50], Step [40/47], Loss: 0.7130
# Epoch [18/50], Step [10/47], Loss: 0.6633
# Epoch [18/50], Step [20/47], Loss: 0.7867
# Epoch [18/50], Step [30/47], Loss: 0.6802
# Epoch [18/50], Step [40/47], Loss: 0.7466
# Epoch [19/50], Step [10/47], Loss: 0.7489
# Epoch [19/50], Step [20/47], Loss: 0.6950
# Epoch [19/50], Step [30/47], Loss: 0.6217
# Epoch [19/50], Step [40/47], Loss: 0.6925
# Epoch [20/50], Step [10/47], Loss: 0.6063
# Epoch [20/50], Step [20/47], Loss: 0.6170
# Epoch [20/50], Step [30/47], Loss: 0.6752
# Epoch [20/50], Step [40/47], Loss: 0.3871
# Epoch [21/50], Step [10/47], Loss: 0.5237
# Epoch [21/50], Step [20/47], Loss: 0.7620
# Epoch [21/50], Step [30/47], Loss: 0.5948
# Epoch [21/50], Step [40/47], Loss: 0.5962
# Epoch [22/50], Step [10/47], Loss: 0.5059
# Epoch [22/50], Step [20/47], Loss: 0.5782
# Epoch [22/50], Step [30/47], Loss: 0.6339
# Epoch [22/50], Step [40/47], Loss: 0.5256
# Epoch [23/50], Step [10/47], Loss: 0.6208
# Epoch [23/50], Step [20/47], Loss: 0.5123
# Epoch [23/50], Step [30/47], Loss: 0.6065
# Epoch [23/50], Step [40/47], Loss: 0.6582
# Epoch [24/50], Step [10/47], Loss: 0.5389
# Epoch [24/50], Step [20/47], Loss: 0.5870
# Epoch [24/50], Step [30/47], Loss: 0.5661
# Epoch [24/50], Step [40/47], Loss: 0.4439
# Epoch [25/50], Step [10/47], Loss: 0.4782
# Epoch [25/50], Step [20/47], Loss: 0.5772
# Epoch [25/50], Step [30/47], Loss: 0.5036
# Epoch [25/50], Step [40/47], Loss: 0.4983
# Epoch [26/50], Step [10/47], Loss: 0.5664
# Epoch [26/50], Step [20/47], Loss: 0.5566
# Epoch [26/50], Step [30/47], Loss: 0.4544
# Epoch [26/50], Step [40/47], Loss: 0.4268
# Epoch [27/50], Step [10/47], Loss: 0.5505
# Epoch [27/50], Step [20/47], Loss: 0.4096
# Epoch [27/50], Step [30/47], Loss: 0.4958
# Epoch [27/50], Step [40/47], Loss: 0.4922
# Epoch [28/50], Step [10/47], Loss: 0.4737
# Epoch [28/50], Step [20/47], Loss: 0.3904
# Epoch [28/50], Step [30/47], Loss: 0.4011
# Epoch [28/50], Step [40/47], Loss: 0.4456
# Epoch [29/50], Step [10/47], Loss: 0.6391
# Epoch [29/50], Step [20/47], Loss: 0.4657
# Epoch [29/50], Step [30/47], Loss: 0.5230
# Epoch [29/50], Step [40/47], Loss: 0.3829
# Epoch [30/50], Step [10/47], Loss: 0.4009
# Epoch [30/50], Step [20/47], Loss: 0.4158
# Epoch [30/50], Step [30/47], Loss: 0.3395
# Epoch [30/50], Step [40/47], Loss: 0.4506
# Epoch [31/50], Step [10/47], Loss: 0.4420
# Epoch [31/50], Step [20/47], Loss: 0.3614
# Epoch [31/50], Step [30/47], Loss: 0.4358
# Epoch [31/50], Step [40/47], Loss: 0.4235
# Epoch [32/50], Step [10/47], Loss: 0.4437
# Epoch [32/50], Step [20/47], Loss: 0.3024
# Epoch [32/50], Step [30/47], Loss: 0.4237
# Epoch [32/50], Step [40/47], Loss: 0.4627
# Epoch [33/50], Step [10/47], Loss: 0.3385
# Epoch [33/50], Step [20/47], Loss: 0.3600
# Epoch [33/50], Step [30/47], Loss: 0.4125
# Epoch [33/50], Step [40/47], Loss: 0.5071
# Epoch [34/50], Step [10/47], Loss: 0.3479
# Epoch [34/50], Step [20/47], Loss: 0.3954
# Epoch [34/50], Step [30/47], Loss: 0.3037
# Epoch [34/50], Step [40/47], Loss: 0.4200
# Epoch [35/50], Step [10/47], Loss: 0.5635
# Epoch [35/50], Step [20/47], Loss: 0.4510
# Epoch [35/50], Step [30/47], Loss: 0.2605
# Epoch [35/50], Step [40/47], Loss: 0.3782
# Epoch [36/50], Step [10/47], Loss: 0.4114
# Epoch [36/50], Step [20/47], Loss: 0.4125
# Epoch [36/50], Step [30/47], Loss: 0.4236
# Epoch [36/50], Step [40/47], Loss: 0.2654
# Epoch [37/50], Step [10/47], Loss: 0.2481
# Epoch [37/50], Step [20/47], Loss: 0.4127
# Epoch [37/50], Step [30/47], Loss: 0.4192
# Epoch [37/50], Step [40/47], Loss: 0.3239
# Epoch [38/50], Step [10/47], Loss: 0.2796
# Epoch [38/50], Step [20/47], Loss: 0.3549
# Epoch [38/50], Step [30/47], Loss: 0.3499
# Epoch [38/50], Step [40/47], Loss: 0.4276
# Epoch [39/50], Step [10/47], Loss: 0.3720
# Epoch [39/50], Step [20/47], Loss: 0.3033
# Epoch [39/50], Step [30/47], Loss: 0.3805
# Epoch [39/50], Step [40/47], Loss: 0.3970
# Epoch [40/50], Step [10/47], Loss: 0.4319
# Epoch [40/50], Step [20/47], Loss: 0.3857
# Epoch [40/50], Step [30/47], Loss: 0.3440
# Epoch [40/50], Step [40/47], Loss: 0.4231
# Epoch [41/50], Step [10/47], Loss: 0.3342
# Epoch [41/50], Step [20/47], Loss: 0.4023
# Epoch [41/50], Step [30/47], Loss: 0.5098
# Epoch [41/50], Step [40/47], Loss: 0.4706
# Epoch [42/50], Step [10/47], Loss: 0.2312
# Epoch [42/50], Step [20/47], Loss: 0.3683
# Epoch [42/50], Step [30/47], Loss: 0.2796
# Epoch [42/50], Step [40/47], Loss: 0.4480
# Epoch [43/50], Step [10/47], Loss: 0.3926
# Epoch [43/50], Step [20/47], Loss: 0.3726
# Epoch [43/50], Step [30/47], Loss: 0.3500
# Epoch [43/50], Step [40/47], Loss: 0.3761
# Epoch [44/50], Step [10/47], Loss: 0.3487
# Epoch [44/50], Step [20/47], Loss: 0.3390
# Epoch [44/50], Step [30/47], Loss: 0.3715
# Epoch [44/50], Step [40/47], Loss: 0.3025
# Epoch [45/50], Step [10/47], Loss: 0.3484
# Epoch [45/50], Step [20/47], Loss: 0.2340
# Epoch [45/50], Step [30/47], Loss: 0.3563
# Epoch [45/50], Step [40/47], Loss: 0.3806
# Epoch [46/50], Step [10/47], Loss: 0.3077
# Epoch [46/50], Step [20/47], Loss: 0.2812
# Epoch [46/50], Step [30/47], Loss: 0.3763
# Epoch [46/50], Step [40/47], Loss: 0.4110
# Epoch [47/50], Step [10/47], Loss: 0.3106
# Epoch [47/50], Step [20/47], Loss: 0.2782
# Epoch [47/50], Step [30/47], Loss: 0.3491
# Epoch [47/50], Step [40/47], Loss: 0.3606
# Epoch [48/50], Step [10/47], Loss: 0.2984
# Epoch [48/50], Step [20/47], Loss: 0.3761
# Epoch [48/50], Step [30/47], Loss: 0.3562
# Epoch [48/50], Step [40/47], Loss: 0.3273
# Epoch [49/50], Step [10/47], Loss: 0.3629
# Epoch [49/50], Step [20/47], Loss: 0.2613
# Epoch [49/50], Step [30/47], Loss: 0.3664
# Epoch [49/50], Step [40/47], Loss: 0.3508
# Epoch [50/50], Step [10/47], Loss: 0.3023
# Epoch [50/50], Step [20/47], Loss: 0.2779
# Epoch [50/50], Step [30/47], Loss: 0.2463
# Epoch [50/50], Step [40/47], Loss: 0.3202

# %%
# Test the model
def test(model, test_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)  # Move data to GPU

            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print(f"Test Accuracy: {100 * correct / total:.2f}%")


# Test the model after training
test(model, val_loader)
# Out:
# Test Accuracy: 87.50%

# %%
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 4770

# %%
# for i in model.fc1.parameters():
#     print(i)

# %%
# 1, 2, 4, 5, 10
# weight_sharing_parameter_num_list = [3042, 3234, 3618, 3810, 4770]

# weight_sharing_test_acc_list = [
#                                 [56.25, 89.43, 95.58, 96.95, 97.61],
#                                 [57.55, 86.67, 95.21, 96.27, 97.86],
#                                 [59.63, 88.32, 95.71, 96.51, 97.92]
#                                 ]

weight_sharing_parameter_num_list = [3042, 3234, 3618, 3810, 4770]

weight_sharing_test_acc_list = [
    [
        37.00,
    ],
    [
        38.33,
    ],
    [
        38.83,
    ],
]
