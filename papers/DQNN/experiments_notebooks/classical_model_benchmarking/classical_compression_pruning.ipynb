# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import torch.nn.utils.prune as prune
from torch.utils.data import DataLoader
from utils import MNIST_partial, accuracy, plot_training_metrics

# %%
# Hyperparameters
learning_rate = 1e-3
num_epochs = 50

# Data loading and preprocessing
# transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# train_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
# train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

# test_dataset = datasets.MNIST(root='./data', train=False, transform=transform, download=True)
# test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# dataset from csv file, to use for the challenge
train_dataset = MNIST_partial(split="train")
val_dataset = MNIST_partial(split="val")

# definition of the dataloader, to process the data in the model
# here, we need a batch size of 1 to use the boson sampler
batch_size = 128
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size, shuffle=False)


# Define the CNN model
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=5)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(8, 12, kernel_size=5)
        self.fc1 = nn.Linear(12 * 4 * 4, 20)
        self.fc2 = nn.Linear(20, 10)

    def forward(self, x):
        x = self.pool(self.conv1(x))
        x = self.pool(self.conv2(x))
        x = x.view(x.size(0), -1)  # Flatten the tensor
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %%
# Instantiate the model, loss function, and optimizer
model = CNNModel()
criterion = nn.CrossEntropyLoss()

# %%
# Apply structured pruning to the convolutional and fully connected layers
def apply_pruning(module, amount=0.3):
    """Apply structured pruning to convolutional and fully connected layers."""
    for name, layer in module.named_modules():
        if isinstance(layer, nn.Conv2d):
            # Prune entire filters (along dim=0) based on L2 norm
            prune.ln_structured(layer, name="weight", amount=amount, n=2, dim=0)
            print(
                f"Applied structured pruning to Conv2d layer {name} with {amount * 100:.1f}% filters pruned."
            )
        elif isinstance(layer, nn.Linear):
            # Prune entire neurons (along dim=1) based on L2 norm
            prune.ln_structured(layer, name="weight", amount=amount, n=2, dim=1)
            print(
                f"Applied structured pruning to Linear layer {name} with {amount * 100:.1f}% neurons pruned."
            )


# Check how many non-zero weights remain after pruning
def print_nonzero_weights(model):
    """Print the percentage of remaining non-zero weights in the model."""
    total_params, nonzero_params = 0, 0
    for name, param in model.named_parameters():
        if "weight" in name or "bias" in name:
            total_params += param.numel()
            nonzero_params += param.nonzero().size(0)
    print(
        f"Non-zero parameters: {nonzero_params}/{total_params} ({100 * nonzero_params / total_params:.2f}%)"
    )

# %%
apply_pruning(model, amount=0.5)
# Remove pruning to finalize the reduced model
for name, layer in model.named_modules():
    if isinstance(layer, (nn.Conv2d, nn.Linear)):
        prune.remove(layer, "weight")

print_nonzero_weights(model)

print(sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# Applied structured pruning to Conv2d layer conv1 with 50.0% filters pruned.
# Applied structured pruning to Conv2d layer conv2 with 50.0% filters pruned.
# Applied structured pruning to Linear layer fc1 with 50.0% neurons pruned.
# Applied structured pruning to Linear layer fc2 with 50.0% neurons pruned.
# Non-zero parameters: 3370/6690 (50.37%)
# 6690

# %%
# for name, param in model.named_parameters():
#     print(param)

# %%
def get_non_pruned_params(model):
    """Get parameters that are not pruned to pass to the optimizer."""
    params = []
    for name, param in model.named_parameters():
        # Include only parameters that are not masked with 'weight_orig'
        if "weight_orig" in name:
            print(param)
        if "weight_orig" not in name:
            params.append(param)
    return params


class MaskedAdam(torch.optim.Adam):
    def __init__(self, params, **kwargs):
        super().__init__(params, **kwargs)

    def step(self, closure=None):
        """Override the step function to skip updates for zeroed weights."""
        for group in self.param_groups:
            for param in group["params"]:
                if param.grad is None:
                    continue

                # Mask the gradients: set gradient to zero where parameter is zero
                grad_mask = (
                    param.data != 0
                )  # Boolean mask: True where weights are non-zero
                param.grad.data.mul_(grad_mask)  # Zero-out gradients for zeroed weights

        # Call the original Adam step function
        super().step(closure)


optimizer = MaskedAdam(model.parameters(), lr=learning_rate)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# CNNModel(
#   (conv1): Conv2d(1, 8, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(8, 12, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=192, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=10, bias=True)
# )

# %%
# Training loop
for epoch in range(num_epochs):
    model.train()
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)  # Move data to GPU

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        if (i + 1) % 10 == 0:
            print(
                f"Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}"
            )
# Out:
# Epoch [1/50], Step [10/47], Loss: 2.3067
# Epoch [1/50], Step [20/47], Loss: 2.2942
# Epoch [1/50], Step [30/47], Loss: 2.2729
# Epoch [1/50], Step [40/47], Loss: 2.2367
# Epoch [2/50], Step [10/47], Loss: 2.0399
# Epoch [2/50], Step [20/47], Loss: 1.8464
# Epoch [2/50], Step [30/47], Loss: 1.4604
# Epoch [2/50], Step [40/47], Loss: 1.3604
# Epoch [3/50], Step [10/47], Loss: 0.9088
# Epoch [3/50], Step [20/47], Loss: 0.9148
# Epoch [3/50], Step [30/47], Loss: 0.6571
# Epoch [3/50], Step [40/47], Loss: 0.7637
# Epoch [4/50], Step [10/47], Loss: 0.6455
# Epoch [4/50], Step [20/47], Loss: 0.5014
# Epoch [4/50], Step [30/47], Loss: 0.4482
# Epoch [4/50], Step [40/47], Loss: 0.5298
# Epoch [5/50], Step [10/47], Loss: 0.7038
# Epoch [5/50], Step [20/47], Loss: 0.4305
# Epoch [5/50], Step [30/47], Loss: 0.4194
# Epoch [5/50], Step [40/47], Loss: 0.3631
# Epoch [6/50], Step [10/47], Loss: 0.2794
# Epoch [6/50], Step [20/47], Loss: 0.3777
# Epoch [6/50], Step [30/47], Loss: 0.3482
# Epoch [6/50], Step [40/47], Loss: 0.4692
# Epoch [7/50], Step [10/47], Loss: 0.3244
# Epoch [7/50], Step [20/47], Loss: 0.3448
# Epoch [7/50], Step [30/47], Loss: 0.3129
# Epoch [7/50], Step [40/47], Loss: 0.3174
# Epoch [8/50], Step [10/47], Loss: 0.2086
# Epoch [8/50], Step [20/47], Loss: 0.3771
# Epoch [8/50], Step [30/47], Loss: 0.3549
# Epoch [8/50], Step [40/47], Loss: 0.4312
# Epoch [9/50], Step [10/47], Loss: 0.3555
# Epoch [9/50], Step [20/47], Loss: 0.2296
# Epoch [9/50], Step [30/47], Loss: 0.2403
# Epoch [9/50], Step [40/47], Loss: 0.2449
# Epoch [10/50], Step [10/47], Loss: 0.3730
# Epoch [10/50], Step [20/47], Loss: 0.3505
# Epoch [10/50], Step [30/47], Loss: 0.2475
# Epoch [10/50], Step [40/47], Loss: 0.4294
# Epoch [11/50], Step [10/47], Loss: 0.2287
# Epoch [11/50], Step [20/47], Loss: 0.2761
# Epoch [11/50], Step [30/47], Loss: 0.2117
# Epoch [11/50], Step [40/47], Loss: 0.3307
# Epoch [12/50], Step [10/47], Loss: 0.1696
# Epoch [12/50], Step [20/47], Loss: 0.2026
# Epoch [12/50], Step [30/47], Loss: 0.2311
# Epoch [12/50], Step [40/47], Loss: 0.1623
# Epoch [13/50], Step [10/47], Loss: 0.2669
# Epoch [13/50], Step [20/47], Loss: 0.3821
# Epoch [13/50], Step [30/47], Loss: 0.2905
# Epoch [13/50], Step [40/47], Loss: 0.1991
# Epoch [14/50], Step [10/47], Loss: 0.2531
# Epoch [14/50], Step [20/47], Loss: 0.3347
# Epoch [14/50], Step [30/47], Loss: 0.2068
# Epoch [14/50], Step [40/47], Loss: 0.1573
# Epoch [15/50], Step [10/47], Loss: 0.3125
# Epoch [15/50], Step [20/47], Loss: 0.1481
# Epoch [15/50], Step [30/47], Loss: 0.1910
# Epoch [15/50], Step [40/47], Loss: 0.1763
# Epoch [16/50], Step [10/47], Loss: 0.1806
# Epoch [16/50], Step [20/47], Loss: 0.2284
# Epoch [16/50], Step [30/47], Loss: 0.2642
# Epoch [16/50], Step [40/47], Loss: 0.2232
# Epoch [17/50], Step [10/47], Loss: 0.2720
# Epoch [17/50], Step [20/47], Loss: 0.1606
# Epoch [17/50], Step [30/47], Loss: 0.2318
# Epoch [17/50], Step [40/47], Loss: 0.1955
# Epoch [18/50], Step [10/47], Loss: 0.1869
# Epoch [18/50], Step [20/47], Loss: 0.1626
# Epoch [18/50], Step [30/47], Loss: 0.1260
# Epoch [18/50], Step [40/47], Loss: 0.3115
# Epoch [19/50], Step [10/47], Loss: 0.2243
# Epoch [19/50], Step [20/47], Loss: 0.1766
# Epoch [19/50], Step [30/47], Loss: 0.1726
# Epoch [19/50], Step [40/47], Loss: 0.2619
# Epoch [20/50], Step [10/47], Loss: 0.1785
# Epoch [20/50], Step [20/47], Loss: 0.2158
# Epoch [20/50], Step [30/47], Loss: 0.1333
# Epoch [20/50], Step [40/47], Loss: 0.1953
# Epoch [21/50], Step [10/47], Loss: 0.1520
# Epoch [21/50], Step [20/47], Loss: 0.1684
# Epoch [21/50], Step [30/47], Loss: 0.1608
# Epoch [21/50], Step [40/47], Loss: 0.0965
# Epoch [22/50], Step [10/47], Loss: 0.1807
# Epoch [22/50], Step [20/47], Loss: 0.1710
# Epoch [22/50], Step [30/47], Loss: 0.1903
# Epoch [22/50], Step [40/47], Loss: 0.2132
# Epoch [23/50], Step [10/47], Loss: 0.2689
# Epoch [23/50], Step [20/47], Loss: 0.2086
# Epoch [23/50], Step [30/47], Loss: 0.2140
# Epoch [23/50], Step [40/47], Loss: 0.1102
# Epoch [24/50], Step [10/47], Loss: 0.2377
# Epoch [24/50], Step [20/47], Loss: 0.1545
# Epoch [24/50], Step [30/47], Loss: 0.0736
# Epoch [24/50], Step [40/47], Loss: 0.1901
# Epoch [25/50], Step [10/47], Loss: 0.1425
# Epoch [25/50], Step [20/47], Loss: 0.1048
# Epoch [25/50], Step [30/47], Loss: 0.2325
# Epoch [25/50], Step [40/47], Loss: 0.1565
# Epoch [26/50], Step [10/47], Loss: 0.2827
# Epoch [26/50], Step [20/47], Loss: 0.1183
# Epoch [26/50], Step [30/47], Loss: 0.1733
# Epoch [26/50], Step [40/47], Loss: 0.1118
# Epoch [27/50], Step [10/47], Loss: 0.1357
# Epoch [27/50], Step [20/47], Loss: 0.1322
# Epoch [27/50], Step [30/47], Loss: 0.2051
# Epoch [27/50], Step [40/47], Loss: 0.1108
# Epoch [28/50], Step [10/47], Loss: 0.2301
# Epoch [28/50], Step [20/47], Loss: 0.1696
# Epoch [28/50], Step [30/47], Loss: 0.1540
# Epoch [28/50], Step [40/47], Loss: 0.2697
# Epoch [29/50], Step [10/47], Loss: 0.0668
# Epoch [29/50], Step [20/47], Loss: 0.1356
# Epoch [29/50], Step [30/47], Loss: 0.3123
# Epoch [29/50], Step [40/47], Loss: 0.2068
# Epoch [30/50], Step [10/47], Loss: 0.0962
# Epoch [30/50], Step [20/47], Loss: 0.0767
# Epoch [30/50], Step [30/47], Loss: 0.1505
# Epoch [30/50], Step [40/47], Loss: 0.1165
# Epoch [31/50], Step [10/47], Loss: 0.1370
# Epoch [31/50], Step [20/47], Loss: 0.0974
# Epoch [31/50], Step [30/47], Loss: 0.1679
# Epoch [31/50], Step [40/47], Loss: 0.1124
# Epoch [32/50], Step [10/47], Loss: 0.0886
# Epoch [32/50], Step [20/47], Loss: 0.1404
# Epoch [32/50], Step [30/47], Loss: 0.1394
# Epoch [32/50], Step [40/47], Loss: 0.1953
# Epoch [33/50], Step [10/47], Loss: 0.1466
# Epoch [33/50], Step [20/47], Loss: 0.1246
# Epoch [33/50], Step [30/47], Loss: 0.2525
# Epoch [33/50], Step [40/47], Loss: 0.0891
# Epoch [34/50], Step [10/47], Loss: 0.1566
# Epoch [34/50], Step [20/47], Loss: 0.0675
# Epoch [34/50], Step [30/47], Loss: 0.1649
# Epoch [34/50], Step [40/47], Loss: 0.0627
# Epoch [35/50], Step [10/47], Loss: 0.0974
# Epoch [35/50], Step [20/47], Loss: 0.1214
# Epoch [35/50], Step [30/47], Loss: 0.0788
# Epoch [35/50], Step [40/47], Loss: 0.1026
# Epoch [36/50], Step [10/47], Loss: 0.0896
# Epoch [36/50], Step [20/47], Loss: 0.0876
# Epoch [36/50], Step [30/47], Loss: 0.0814
# Epoch [36/50], Step [40/47], Loss: 0.1690
# Epoch [37/50], Step [10/47], Loss: 0.1182
# Epoch [37/50], Step [20/47], Loss: 0.1330
# Epoch [37/50], Step [30/47], Loss: 0.0982
# Epoch [37/50], Step [40/47], Loss: 0.1951
# Epoch [38/50], Step [10/47], Loss: 0.1192
# Epoch [38/50], Step [20/47], Loss: 0.1340
# Epoch [38/50], Step [30/47], Loss: 0.1102
# Epoch [38/50], Step [40/47], Loss: 0.0846
# Epoch [39/50], Step [10/47], Loss: 0.1988
# Epoch [39/50], Step [20/47], Loss: 0.1215
# Epoch [39/50], Step [30/47], Loss: 0.1596
# Epoch [39/50], Step [40/47], Loss: 0.1073
# Epoch [40/50], Step [10/47], Loss: 0.0790
# Epoch [40/50], Step [20/47], Loss: 0.0967
# Epoch [40/50], Step [30/47], Loss: 0.1040
# Epoch [40/50], Step [40/47], Loss: 0.0927
# Epoch [41/50], Step [10/47], Loss: 0.0750
# Epoch [41/50], Step [20/47], Loss: 0.1077
# Epoch [41/50], Step [30/47], Loss: 0.1449
# Epoch [41/50], Step [40/47], Loss: 0.0825
# Epoch [42/50], Step [10/47], Loss: 0.1587
# Epoch [42/50], Step [20/47], Loss: 0.1201
# Epoch [42/50], Step [30/47], Loss: 0.1580
# Epoch [42/50], Step [40/47], Loss: 0.0860
# Epoch [43/50], Step [10/47], Loss: 0.1288
# Epoch [43/50], Step [20/47], Loss: 0.2781
# Epoch [43/50], Step [30/47], Loss: 0.1758
# Epoch [43/50], Step [40/47], Loss: 0.1655
# Epoch [44/50], Step [10/47], Loss: 0.1020
# Epoch [44/50], Step [20/47], Loss: 0.1019
# Epoch [44/50], Step [30/47], Loss: 0.1322
# Epoch [44/50], Step [40/47], Loss: 0.0689
# Epoch [45/50], Step [10/47], Loss: 0.1353
# Epoch [45/50], Step [20/47], Loss: 0.1245
# Epoch [45/50], Step [30/47], Loss: 0.1520
# Epoch [45/50], Step [40/47], Loss: 0.1148
# Epoch [46/50], Step [10/47], Loss: 0.0604
# Epoch [46/50], Step [20/47], Loss: 0.1596
# Epoch [46/50], Step [30/47], Loss: 0.1076
# Epoch [46/50], Step [40/47], Loss: 0.1004
# Epoch [47/50], Step [10/47], Loss: 0.1055
# Epoch [47/50], Step [20/47], Loss: 0.1907
# Epoch [47/50], Step [30/47], Loss: 0.2378
# Epoch [47/50], Step [40/47], Loss: 0.0633
# Epoch [48/50], Step [10/47], Loss: 0.0674
# Epoch [48/50], Step [20/47], Loss: 0.0932
# Epoch [48/50], Step [30/47], Loss: 0.1014
# Epoch [48/50], Step [40/47], Loss: 0.0753
# Epoch [49/50], Step [10/47], Loss: 0.0628
# Epoch [49/50], Step [20/47], Loss: 0.1165
# Epoch [49/50], Step [30/47], Loss: 0.0650
# Epoch [49/50], Step [40/47], Loss: 0.0812
# Epoch [50/50], Step [10/47], Loss: 0.1138
# Epoch [50/50], Step [20/47], Loss: 0.0668
# Epoch [50/50], Step [30/47], Loss: 0.0493
# Epoch [50/50], Step [40/47], Loss: 0.0913

# %%
# Evaluate the pruned model
def evaluate(model, test_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)  # Move data to GPU

            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print(f"Test Accuracy: {100 * correct / total:.2f}%")


evaluate(model, val_loader)


# print("Pruning removed. Model restored to dense weights.")
# Out:
# Test Accuracy: 95.33%

# %%
print_nonzero_weights(model)
# Out:
# Non-zero parameters: 3370/6690 (50.37%)

# %%
# MNIST partial

pruning_parameter_num_list = [675, 1300, 2120, 2745, 3370]

pruning_test_acc_list = [
    [29.00, 76.33, 86.67, 91.17, 95.33],
    [21.50, 77.50, 89.67, 91.17, 93.17],
    [33.17, 80.17, 90.00, 92.17, 94.83],
]
